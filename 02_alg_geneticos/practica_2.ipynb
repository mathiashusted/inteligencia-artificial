# %% [markdown]
# # Práctica 2 - Inteligencia Artificial
#
# ### Grado Ingeniería Informática Tecnologías Informáticas
#
# ### Técnicas metaheurísticas para optimización
# ### Algoritmos Genéticos
#
# Miguel A. Gutérrez Naranjo - 10 de octubre, 2022.

# %% [markdown]
# La Gioconda es un óleo sobre tabla de álamo de 77 × 53 cm, pintado entre 1503 y 1519 por Leonardo da Vinci. En esta práctica vamos a usar algoritmos genéticos para aproximar esa imagen mediante rectángulos en escala de grises.

# %% [markdown]
# <img src="gioconda.jpg">

# %% [markdown]
# Usaremos una representación muy básica y se espera que, tras realizar la práctica, el alumno sea capaz de probar con otros polígonos y pasar de la escala de grises a imágenes en color. También es interesante buscar otras definiciones de la función decodifica, que permite generar la imagen a partir del cromosoma, otras funciones de *fitness* y otros algoritmos genéticos. En la práctica, consideraremos poblaciones de individuos, donde cada individuo se represantará mediante una tupla de genes. Además, cada individuo tendrá asociado un determinado valor *fitness* para poder comparar entre ellos. Cada gen será una tupla $(x,y,dx,dy,c)$ que interpretaremos como un rectángulo con extremo superior izquierda $(x,y)$, lados $dx$ y $dy$ y $c\in \{0,1,\dots,255\}$ representa su color (en escala de grises).

# %% [markdown]
# En primer lugar cargamos las librerías que vamos a necesitar.

# %%
# 1.- numpy para la representación matricial
import numpy as np

# 2.- random para poder tomar valores aleatorios
import random, math

# 3.- PIL e imageio para leer y escribir imágenes.
from PIL import Image
import imageio

# Para dibujar
import matplotlib as mpl
from matplotlib import pyplot as plt
mpl.rcParams['figure.figsize'] = (15,10) # Para el tamaño de la imagen

# Importamos la similaridad estructural de skimage.metrics
from skimage.metrics import structural_similarity as ssim

# %% [markdown]
# Para empezar, tomamos la imagen que queremos aproximar desde un fichero y lo guardamos como una imagen python (en este caso el fichero gioconda.jpg). Para ello
# usamos la librería PIL para convertir la imagen en una imagen en escala de grises de 8-bits (256 valores). Ver
# https://pillow.readthedocs.io/en/3.1.x/handbook/concepts.html#concept-modes

# %%
imagen_original = 'gioconda.jpg'
img = Image.open(imagen_original).convert('L')

# %% [markdown]
# Podemos ver la imagen una vez transformada

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# A continuación, transformamos la imagen en una matriz de valores comprendido entre 0 y 255 mediante la librería numpy. Es importante saber que al cambiar el tipo de dato de imagen a matriz se cambian los ejes
# https://stackoverflow.com/questions/33725237/image-fromarray-changes-size.
# Llamamos IM2ARRAY a la matriz que guarda las intensidades de gris de los píxeles.

# %%
IM2ARRAY = np.array(img)

# %% [markdown]
# Podemos ver qué aspecto tiene

# %%
IM2ARRAY
# Out:
# array([[ 22,  47,  38, ...,  28,  34,  34],
#        [ 87, 131,  97, ...,  26,  31,  20],
#        [113, 117,  77, ...,  79,  79,  54],
#        ...,
#        [ 42, 102,  93, ...,  83,  77,  31],
#        [ 16,  31,  17, ...,  69,  64,  31],
#        [ 38,  33,  24, ...,  35,  35,  18]], dtype=uint8)

# %% [markdown]
# Guardamos el tamaño de la matriz en la variable *im2array_shape* para poder crear otras matrices con el mismo tamaño.

# %%
im2array_shape = IM2ARRAY.shape

# %%
im2array_shape
# Out:
# (364, 245)

# %% [markdown]
# A continuación fijamos los parámetros del algoritmo genético para aproximar la imagen original mediante rectángulos en escala de grises.

# %%
# Número de genes que conforman un individuo
NUMERO_DE_GENES = 150

# Tamaño de la población
TAMANO_POB = 500

# Participantes en un torneo
NUM_PARTICIPANTES = 10

# Probabilidad de mutación
PROB_MUTACION = 0.2

# Proporción de individuos que van a ser padres
PROP_CRUCES = 0.5

# Número de iteraciones
ITERACIONES = 50001

# Paso de impresión. Crearemos la imagen correspondiente al mejor individuo después de PASO_IMP iteraciones
PASO_IMP = 250

# %% [markdown]
# ### Ejercicio 1
# Define la función genera_gen() que a partir de la variable *im2array_shape* devuelva una tupla $(x,y,dx,dy,c)$. Una vez fijado el extremo $(x,y)$ dentro del lienzo, debemos tener en cuenta que el rectángulo esté dentro del lienzo y que el color esté en el rango 0-255.

# %%
# Solución
def genera_gen(im2array_shape):
    x = random.randint(0, im2array_shape[0])
    y = random.randint(0, im2array_shape[1])
    dx = random.randint(0, im2array_shape[0] - x)
    dy = random.randint(0, im2array_shape[0] - y)
    c = random.randint(0, 255)

    return x, y, dx, dy, c

# %%
# Puedes probar la función
genera_gen(im2array_shape)

# Posible respuesta:
# (185, 223, 49, 16, 2)
# Out:
# (198, 167, 42, 176, 29)

# %% [markdown]
# ### Ejercicio 2
# Define genera_individuo() que devuelva una tupla con tantos genes como determine el parámetro *NUMERO_DE_GENES*

# %%
# Solución

def genera_individuo(NUMERO_DE_GENES, im2array_shape):
    genes = [genera_gen(im2array_shape) for _ in range(NUMERO_DE_GENES)]
    return tuple(genes)

# %%
# Ejemplo de uso. Guardamos el individuo generado en la variable ind_1
ind_1 = genera_individuo(20, im2array_shape)
ind_1

# Posible respuesta:
# ((53, 10, 80, 200, 114),
#  (271, 209, 6, 4, 135),
#  ...
#  (310, 220, 35, 19, 174),
#  (264, 121, 37, 45, 200))
# Out:
# ((45, 99, 298, 72, 122),
#  (219, 94, 23, 228, 129),
#  (179, 193, 49, 98, 197),
#  (230, 208, 12, 130, 168),
#  (216, 63, 139, 299, 253),
#  (134, 231, 17, 18, 156),
#  (335, 173, 6, 100, 245),
#  (62, 238, 107, 13, 80),
#  (26, 213, 108, 74, 123),
#  (223, 15, 6, 62, 6),
#  (23, 5, 206, 341, 190),
#  (287, 144, 28, 117, 254),
#  (193, 61, 127, 197, 61),
#  (142, 27, 94, 2, 210),
#  (247, 158, 12, 148, 194),
#  (122, 84, 218, 79, 211),
#  (101, 17, 18, 273, 170),
#  (314, 107, 49, 183, 123),
#  (362, 167, 1, 124, 34),
#  (301, 229, 41, 25, 59))

# %% [markdown]
# Cada gen representa un rectángulo dentro del lienzo y un individuo es una sucesión de genes. Para poder interpretar ese individuo como una imagen, primero generamos una matriz (array) a partir de ese conjunto de genes. En este caso, las posiciones que no están ocupadas por ningún cuadrado las interpretamos como blanco (valor 255) y en el resto de la posiciones se sumará la intensidad de los rectángulos que las ocupan. La función *decodifica* crea una matriz con la intensidad de gris de cada píxel a partir de un individuo.

# %%
# Solución:
def decodifica(ind):
    array_sal = np.zeros(im2array_shape,dtype='uint32')
    array_255 = np.full(im2array_shape,255,dtype='uint32')   
    for (x,y,dx,dy,c) in ind:
        array_sal[x:x+dx,y:y+dy]+= 255 - c
    mini = np.minimum(array_sal,array_255)
    inversa = 255 - mini
    return inversa

# %% [markdown]
# Podemos ver la matriz generada a partir del individuo que hemos creado.

# %%
matriz_1 = decodifica(ind_1)
print(matriz_1.tolist())
# Out:
# [[255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255], [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255], [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255], [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 25 ...

# %% [markdown]
# Podemos ver la imagen correspondiente a ese individuo transformando la matriz en una imagen

# %%
img_1 = Image.fromarray(matriz_1.astype('uint8'))
plt.imshow(img_1,cmap='gray')

# %% [markdown]
# Podemos ver una imagen junto a la otra

# %%
f, axarr = plt.subplots(1,2)
axarr[0].imshow(img,cmap='gray')
axarr[1].imshow(img_1,cmap='gray')

# %% [markdown]
# Obviamente, este individuo es una mala aproximación de la imagen original. Vamos a implementar un algoritmo genético que permita encontrar una mejor aproximación.
#
# Para poder lanzar el algoritmo genético, en primer lugar definimos una función que nos permita crear una población inicial de individuos.

# %% [markdown]
# ### Ejercicio 3
# Define una función poblacion_inicial() que devuelva una lista con tantos individuos como determine la variable *TAMANO_POB*

# %%
# Solución:

TAMANO_POB = 50
NUMERO_DE_GENES = 20

def poblacion_inicial():
    poblacion = [genera_individuo(NUMERO_DE_GENES, im2array_shape) for _ in range(TAMANO_POB)]
    return poblacion

poblacion_inicial()
# Out:
# [((224, 242, 29, 33, 169),
#   (85, 35, 24, 162, 73),
#   (181, 96, 69, 242, 64),
#   (41, 143, 50, 115, 116),
#   (311, 165, 1, 55, 219),
#   (316, 243, 17, 43, 130),
#   (41, 144, 217, 65, 251),
#   (272, 150, 74, 167, 115),
#   (238, 142, 53, 183, 104),
#   (144, 179, 44, 144, 139),
#   (287, 12, 43, 245, 224),
#   (318, 73, 29, 102, 215),
#   (200, 232, 131, 54, 228),
#   (89, 77, 40, 66, 71),
#   (39, 123, 249, 155, 157),
#   (288, 187, 67, 48, 249),
#   (76, 211, 31, 121, 33),
#   (188, 13, 139, 241, 177),
#   (336, 68, 17, 261, 86),
#   (57, 207, 20, 134, 231)),
#  ((345, 14, 19, 130, 97),
#   (22, 96, 209, 200, 104),
#   (183, 79, 125, 95, 244),
#   (197, 7, 148, 258, 51),
#   (351, 163, 5, 34, 90),
#   (103, 108, 232, 123, 248),
#   (305, 215, 17, 70, 241),
#   (0, 184, 140, 131, 204),
#   (343, 203, 1, 49, 55),
#   (259, 199, 14, 144, 214),
#   (223, 45, 79, 163, 115),
#   (36, 32, 134, 76, 220),
#   (311, 37, 34, 261, 41),
#   (222, 178, 95, 175, 242),
#   (357, 220, 3, 46, 165),
#   (165, 36, 10, 13, 152),
#   (11, 18, 295, 147, 228),
#   (317, 236, 40, 127, 203),
#   (228, 185, 70, 1, 7),
#   (239, 198, 24, 35, 210)),
#  ((140, 125, 120, 176, 132),
#   (59, 100, 66, 206, 145),
#   (222, 173, 135, 101, 252),
#   (294, 34, 24, 310, 174),
#   (252, 20, 2, 216, 47),
#   (174, 99, 174, 97, 113),
#   (290, 235, 16, 28, 105),
#   (192, 202, 37, 73, 42),
#   (30, 209, 270, 112, 177),
#   (208, 171, 155, 94, 224),
#   (364, 233, 0, 52, 21),
#   (311, 243, 15, 90, 99),
#   (0, 167, 81, 29, 184),
#   (194, 167, 128, 17, 69),
#   (159, 62, 176, 120, 88),
#   (344, 140, 2, 137, 75),
#   (13, 45, 43, 108, 69),
#   (230, 209, 103, 102, 42),
#   (168, 81, 130, 140, 30),
#   (49, 48, 245, 126, 223)),
#  ((234, 164, 89, 62, 6),
#   (292, 52, 37, 137, 153),
#   (190, 114, 142, 243, 180),
#   (252, 128, 78, 158, 153),
#   (363, 96, 1, 64, 113),
#   (174, 163, 82, 169, 40),
#   (178, 145, 6, 111, 220),
#   (139, 9, 75, 102, 124),
#   (197, 143, 141, 46, 210),
#   (222, 179, 139, 83, 120),
#   (326, 49, 17, 132, 236),
#   (282, 43, 82, 38, 48),
#   (251, 11, 6, 136, 186),
#   (243, 52, 46, 240, 161),
#   (189, 50, 85, 158, 102),
#   (7, 234, 55, 48, 69),
#   (193, 155, 126, 182, 67),
#   (237, 144, 17, 36, 63),
#   (196, 185, 123, 7, 75),
#   (345, 36, 6, 214, 253)),
#  ((289, 183, 50, 83, 220),
#   (133, 144, 105, 81, 41),
#   (80, 62, 142, 252, 170),
#   (68, 52, 1, 151, 234),
#   (160, 205, 140, 119, 134),
#   (282, 160, 60, 174, 243),
#   (222, 28, 31, 69, 10),
#   (62, 214, 25, 144, 31),
#   (74, 212, 250, 32, 24),
#   (93, 86, 200, 254, 193),
#   (348, 14, 12, 158, 186),
#   (338, 62, 10, 115, 149),
#   (92, 56, 180, 227, 64),
#   (128, 8, 195, 55, 202),
#   (211, 188, 23, 146, 166),
#   (281, 191, 74, 156, 194),
#   (235, 238, 92, 15, 52),
#   (272, 245, 76, 3, 150),
#   (111, 184, 111, 69, 132),
#   (352, 134, 2, 145, 118)),
#  ((53, 236, 1, 1, 238),
#   (341, 37, 16, 244, 23),
#   (148, 122, 141, 227, 107),
#   (295, 17, 63, 73, 188),
#   (84, 39, 19, 190, 1),
#   (99, 198, 213, 77, 141),
#   (86, 41, 159, 27, 201),
#   (50, 119, 253, 119, 87),
#   (149, 148, 95, 215, 228),
#   (209, 115, 122, 113, 221),
#   (31, 105, 117, 244, 53),
#   (33, 182, 116, 34, 202),
#   (50, 51, 79, 135, 228),
#   (164, 195, 180, 104, 197),
#   (313, 201, 28, 116, 164),
#   (291, 85, 71, 242, 105),
#   (239, 116, 80, 213, 124),
#   (200, 232, 49, 79, 243),
#   (16, 162, 22, 89, 48),
#   (200, 101, 9, 1, 36)),
#  ((243, 201, 106, 70, 158),
#   (150, 225, 88, 13, 200),
#   (339, 14, 21, 297, 31),
#   (158, 157, 44, 132, 170),
#   (149, 222, 15, 21, 131),
#   (245, 80, 66, 152, 127),
#   (240, 73, 61, 228, 114),
#   (210, 160, 71, 34, 53),
#   (73, 139, 245, 40, 170),
#   (139, 167, 177, 101, 18),
#   (106, 170, 164, 55, 229),
#   (280, 88, 82, 35, 232),
#   (107, 98, 47, 22, 3),
#   (332, 29, 28, 17, 0),
#   (164, 14, 7, 282, 53),
#   (321, 150, 26, 112, 105),
#   (191, 66, 120, 67, 189),
#   (310, 53, 14, 218, 18),
#   (243, 72, 81, 269, 36),
#   (338, 240, 15, 81, 252)),
#  ((210, 178, 89, 115, 20),
#   (311, 32, 52, 23, 58),
#   (219, 234, 102, 71, 7),
#   (101, 55, 182, 117, 216),
#   (127, 168, 185, 39, 85),
#   (24, 69, 234, 135, 235),
#   (353, 45, 3, 95, 80),
#   (305, 88, 29, 11, 146),
#   (133, 156, 151, 104, 244),
#   (148, 182, 80, 48, 163),
#   (139, 169, 6, 125, 198),
#   (109, 91, 202, 268, 129),
#   (308, 169, 25, 19, 234),
#   (304, 188, 19, 53, 194),
#   (111, 176, 243, 69, 57),
#   (117, 52, 94, 223, 16),
#   (165, 49, 183, 170, 128),
#   (156, 130, 47, 211, 130),
#   (254, 47, 80, 67, 222),
#   (228, 90, 106, 119, 233)),
#  ((343, 232, 19, 24, 154),
#   (109, 200, 81, 142, 71),
#   (120, 217, 205, 111, 222),
#   (103, 51, 54, 81, 18),
#   (315, 16, 47, 47, 9),
#   (212, 21, 102, 103, 77),
#   (77, 69, 59, 251, 23),
#   (245, 203, 93, 18, 245),
#   (100, 228, 165, 107, 46),
#   (249, 68, 42, 54, 141),
#   (349, 239, 5, 4, 2),
#   (82, 113, 190, 47, 76),
#   (139, 76, 52, 164, 41),
#   (3, 122, 204, 105, 32),
#   (238, 184, 46, 119, 177),
#   (38, 224, 315, 8, 252),
#   (115, 212, 245, 100, 152),
#   (212, 166, 131, 60, 173),
#   (17, 158, 111, 58, 74),
#   (74, 44, 243, 297, 141)),
#  ((60, 76, 234, 87, 35),
#   (127, 164, 154, 155, 42),
#   (308, 170, 28, 170, 55),
#   (235, 59, 120, 227, 40),
#   (9, 151, 73, 211, 102),
#   (39, 114, 35, 174, 71),
#   (202, 65, 74, 185, 157),
#   (265, 243, 98, 109, 134),
#   (283, 243, 14, 76, 216),
#   (339, 200, 5, 139, 115),
#   (291, 137, 22, 138, 143),
#   (332, 173, 2, 160, 115),
#   (244, 175, 12, 154, 228),
#   (167, 81, 181, 22, 240),
#   (245, 214, 95, 14, 167),
#   (92, 235, 29, 115, 2),
#   (82, 35, 54, 142, 254),
#   (77, 89, 190, 229, 39),
#   (188, 158, 69, 52, 68),
#   (324, 133, 8, 41, 6)),
#  ((234, 11, 62, 164, 58),
#   (42, 32, 188, 264, 169),
#   (336, 245, 21, 69, 60),
#   (187, 62, 170, 265, 248),
#   (21, 109, 318, 246, 235),
#   (16, 122, 296, 178, 109),
#   (32, 119, 179, 23, 28),
#   (95, 23, 40, 65, 201),
#   (235, 155, 9, 59, 164),
#   (314, 110, 14, 44, 173),
#   (353, 185, 10, 152, 60),
#   (282, 10, 63, 318, 21),
#   (252, 98, 99, 108, 55),
#   (158, 118, 78, 101, 201),
#   (296, 30, 10, 116, 3),
#   (356, 37, 6, 303, 146),
#   (139, 24, 37, 318, 33),
#   (337, 87, 3, 209, 220),
#   (197, 32, 16, 233, 253),
#   (321, 161, 11, 162, 190)),
#  ((58, 0, 182, 114, 129),
#   (29, 128, 295, 61, 122),
#   (128, 156, 168, 31, 193),
#   (65, 101, 232, 114, 83),
#   (188, 118, 9, 112, 49),
#   (71, 52, 180, 180, 92),
#   (311, 131, 47, 201, 179),
#   (128, 87, 47, 203, 208),
#   (256, 217, 77, 120, 34),
#   (300, 81, 31, 46, 92),
#   (288, 97, 6, 17, 20),
#   (110, 173, 245, 40, 4),
#   (345, 147, 11, 189, 82),
#   (91, 239, 181, 17, 246),
#   (358, 31, 0, 9, 223),
#   (141, 102, 159, 242, 65),
#   (38, 44, 89, 94, 93),
#   (132, 115, 148, 68, 35),
#   (284, 115, 5, 246, 137),
#   (116, 9, 221, 281, 115)),
#  ((121, 19, 24, 203, 220),
#   (141, 45, 46, 38, 76),
#   (186, 57, 33, 229, 201),
#   (305, 64, 25, 120, 90),
#   (102, 72, 217, 283, 143),
#   (139, 152, 115, 159, 65),
#   (261, 219, 30, 98, 39),
#   (85, 150, 42, 101, 250),
#   (3, 192, 274, 8, 153),
#   (90, 54, 241, 296, 143),
#   (121, 89, 55, 134, 213),
#   (361, 104, 3, 31, 198),
#   (24, 154, 310, 58, 95),
#   (230, 132, 128, 216, 174),
#   (174, 189, 77, 138, 103),
#   (348, 216, 0, 116, 73),
#   (26, 97, 239, 172, 218),
#   (39, 6, 229, 154, 124),
#   (223, 75, 66, 270, 133),
#   (145, 140, 13, 59, 197)),
#  ((19, 130, 265, 42, 208),
#   (47, 207, 52, 138, 55),
#   (79, 215, 180, 83, 93),
#   (267, 237, 82, 115, 51),
#   (68, 22, 33, 25, 128),
#   (247, 193, 64, 150, 160),
#   (8, 155, 52, 108, 40),
#   (264, 220, 67, 132, 210),
#   (169, 19, 132, 337, 248),
#   (67, 163, 28, 78, 181),
#   (244, 235, 24, 32, 83),
#   (214, 56, 126, 230, 2),
#   (271, 196, 16, 137, 218),
#   (239, 55, 19, 243, 35),
#   (39, 228, 184, 7, 11),
#   (208, 168, 144, 22, 216),
#   (14, 98, 324, 129, 171),
#   (28, 9, 106, 239, 86),
#   (336, 37, 24, 281, 108),
#   (37, 158, 259, 9, 163)),
#  ((55, 57, 136, 55, 247),
#   (144, 3, 38, 301, 254),
#   (2, 180, 280, 58, 93),
#   (311, 184, 50, 51, 54),
#   (31, 230, 157, 117, 239),
#   (278, 38, 6, 227, 163),
#   (306, 12, 39, 273, 148),
#   (86, 139, 135, 95, 146),
#   (85, 124, 139, 201, 198),
#   (314, 27, 16, 177, 22),
#   (351, 81, 9, 256, 213),
#   (268, 137, 14, 37, 151),
#   (4, 67, 323, 56, 174),
#   (245, 5, 99, 228, 44),
#   (265, 155, 19, 73, 49),
#   (17, 220, 186, 70, 242),
#   (250, 20, 6, 125, 154),
#   (63, 3, 282, 236, 195),
#   (273, 171, 60, 175, 66),
#   (87, 41, 72, 247, 234)),
#  ((313, 124, 36, 234, 113),
#   (264, 209, 88, 128, 190),
#   (303, 55, 16, 86, 189),
#   (196, 153, 136, 111, 225),
#   (8, 191, 82, 146, 56),
#   (165, 80, 127, 181, 131),
#   (197, 185, 127, 10, 185),
#   (258, 40, 21, 184, 236),
#   (165, 29, 51, 265, 143),
#   (324, 244, 40, 115, 150),
#   (245, 52, 111, 93, 134),
#   (249, 112, 4, 77, 58),
#   (315, 167, 42, 113, 106),
#   (363, 29, 0, 260, 41),
#   (156, 58, 194, 139, 107),
#   (108, 189, 68, 30, 208),
#   (102, 143, 87, 22, 57),
#   (290, 82, 59, 223, 80),
#   (254, 208, 14, 9, 31),
#   (347, 87, 10, 19, 237)),
#  ((97, 66, 213, 126, 48),
#   (337, 197, 19, 68, 25),
#   (223, 97, 115, 55, 102),
#   (174, 95, 44, 223, 232),
#   (273, 238, 90, 89, 15),
#   (331, 103, 16, 64, 15),
#   (60, 126, 205, 5, 180),
#   (106, 10, 222, 319, 145),
#   (146, 21, 2, 195, 198),
#   (212, 156, 102, 90, 26),
#   (156, 149, 75, 197, 134),
#   (311, 207, 39, 18, 113),
#   (177, 53, 163, 258, 240),
#   (77, 9, 14, 53, 7),
#   (4, 122, 319, 10, 208),
#   (26, 138, 97, 226, 76),
#   (189, 222, 107, 61, 218),
#   (131, 81, 143, 80, 134),
#   (149, 112, 192, 85, 14),
#   (219, 119, 1, 22, 251)),
#  ((104, 42, 102, 96, 197),
#   (343, 68, 1, 238, 98),
#   (73, 128, 54, 92, 6),
#   (53, 94, 108, 97, 51),
#   (61, 208, 18, 2, 216),
#   (82, 155, 67, 199, 101),
#   (0, 143, 247, 15, 197),
#   (224, 50, 78, 36, 140),
#   (316, 53, 13, 72, 234),
#   (297, 2, 59, 288, 68),
#   (263, 57, 89, 84, 141),
#   (197, 178, 19, 52, 11),
#   (119, 68, 118, 238, 64),
#   (58, 120, 161, 236, 94),
#   (130, 236, 87, 50, 92),
#   (61, 189, 193, 0, 40),
#   (284, 156, 25, 172, 41),
#   (66, 180, 100, 103, 104),
#   (285, 165, 8, 55, 79),
#   (135, 214, 183, 72, 191)),
#  ((227, 57, 4, 118, 198),
#   (360, 55, 0, 308, 231),
#   (59, 127, 32, 187, 181),
#   (320, 189, 1, 50, 111),
#   (113, 170, 206, 140, 224),
#   (196, 215, 128, 44, 42),
#   (141, 43, 176, 255, 128),
#   (249, 241, 8, 58, 118),
#   (353, 26, 9, 227, 223),
#   (326, 96, 18, 13, 9),
#   (80, 168, 212, 179, 185),
#   (26, 17, 185, 239, 155),
#   (314, 100, 26, 212, 71),
#   (232, 182, 19, 42, 225),
#   (138, 25, 159, 166, 57),
#   (174, 163, 108, 144, 140),
#   (227, 54, 12, 278, 113),
#   (98, 195, 257, 132, 240),
#   (179, 153, 140, 4, 151),
#   (71, 224, 36, 30, 37)),
#  ((322, 160, 0, 201, 101),
#   (340, 108, 2, 132, 212),
#   (169, 38, 13, 221, 239),
#   (226, 237, 104, 30, 24),
#   (93, 189, 187, 2, 158),
#   (224, 230, 139, 38, 74),
#   (287, 116, 67, 146, 127),
#   (70, 156, 250, 22, 226),
#   (345, 10, 4, 28, 155),
#   (219, 9, 102, 319, 30),
#   (87, 92, 274, 3, 186),
#   (62, 101, 123, 211, 159),
#   (109, 87, 177, 239, 80),
#   (351, 48, 8, 141, 23),
#   (333, 197, 25, 42, 160),
#   (184, 185, 95, 6, 39),
#   (31, 70, 79, 4, 146),
#   (189, 91, 105, 208, 15),
#   (190, 175, 71, 94, 170),
#   (232, 9, 106, 97, 72)),
#  ((95, 73, 215, 184, 106),
#   (11, 103, 250, 126, 47),
#   (20, 226, 306, 51, 190),
#   (125, 240, 87, 10, 201),
#   (98, 26, 115, 257, 14),
#   (166, 71, 102, 93, 48),
#   (245, 150, 51, 180, 178),
#   (270, 76, 81, 286, 210),
#   (245, 176, 10, 131, 49),
#   (315, 124, 16, 8, 179),
#   (197, 75, 82, 94, 85),
#   (355, 130, 8, 89, 185),
#   (158, 29, 98, 323, 96),
#   (98, 169, 35, 106, 224),
#   (152, 16, 161, 327, 63),
#   (114, 117, 110, 200, 131),
#   (163, 42, 18, 64, 236),
#   (351, 228, 1, 89, 210),
#   (104, 38, 247, 196, 240),
#   (74, 92, 223, 40, 236)),
#  ((320, 5, 26, 43, 227),
#   (270, 39, 48, 271, 246),
#   (160, 84, 140, 160, 150),
#   (143, 63, 187, 171, 66),
#   (39, 172, 35, 164, 106),
#   (227, 188, 83, 155, 53),
#   (124, 168, 222, 172, 57),
#   (73, 210, 200, 25, 166),
#   (221, 62, 70, 216, 103),
#   (309, 60, 13, 262, 73),
#   (303, 132, 35, 14, 220),
#   (176, 11, 40, 242, 35),
#   (281, 215, 23, 40, 217),
#   (101, 131, 253, 95, 56),
#   (274, 46, 37, 19, 203),
#   (167, 39, 157, 89, 149),
#   (264, 7, 41, 143, 118),
#   (4, 105, 218, 247, 5),
#   (206, 22, 42, 59, 119),
#   (14, 186, 317, 76, 244)),
#  ((32, 179, 279, 177, 0),
#   (30, 79, 164, 133, 85),
#   (293, 67, 31, 229, 228),
#   (44, 145, 221, 219, 242),
#   (221, 140, 23, 141, 215),
#   (72, 94, 125, 163, 132),
#   (39, 55, 53, 292, 119),
#   (205, 35, 139, 298, 250),
#   (122, 67, 128, 39, 103),
#   (143, 71, 118, 118, 37),
#   (278, 219, 66, 32, 151),
#   (192, 221, 24, 137, 128),
#   (294, 145, 51, 94, 23),
#   (152, 120, 29, 214, 75),
#   (359, 137, 0, 42, 89),
#   (92, 67, 7, 20, 162),
#   (118, 199, 182, 31, 61),
#   (8, 164, 68, 99, 107),
#   (54, 80, 213, 143, 8),
#   (363, 155, 1, 11, 156)),
#  ((61, 112, 90, 222, 128),
#   (139, 61, 191, 231, 150),
#   (121, 210, 195, 66, 118),
#   (149, 46, 129, 293, 24),
#   (273, 112, 35, 191, 98),
#   (164, 104, 169, 231, 182),
#   (157, 170, 3, 72, 210),
#   (165, 26, 15, 163, 192),
#   (175, 120, 97, 201, 247),
#   (85, 59, 175, 209, 90),
#   (204, 129, 46, 50, 180),
#   (200, 108, 87, 53, 244),
#   (227, 124, 131, 216, 74),
#   (316, 85, 16, 176, 195),
#   (262, 240, 24, 45, 23),
#   (254, 128, 6, 93, 183),
#   (347, 183, 13, 169, 210),
#   (226, 212, 111, 139, 125),
#   (351, 87, 2, 110, 98),
#   (245, 232, 16, 126, 76)),
#  ((224, 78, 72, 197, 232),
#   (60, 117, 272, 60, 103),
#   (33, 51, 81, 40, 227),
#   (331, 99, 25, 66, 250),
#   (67, 140, 271, 30, 89),
#   (322, 85, 20, 58, 210),
#   (238, 106, 69, 125, 74),
#   (93, 198, 11, 85, 48),
#   (150, 44, 189, 278, 152),
#   (299, 70, 10, 261, 31),
#   (114, 7, 23, 24, 168),
#   (236, 140, 82, 53, 172),
#   (333, 84, 1, 243, 99),
#   (103, 12, 224, 248, 121),
#   (148, 32, 117, 159, 156),
#   (300, 6, 31, 83, 234),
#   (60, 196, 277, 88, 68),
#   (64, 156, 104, 85, 7),
#   (152, 197, 164, 28, 141),
#   (255, 7, 28, 214, 188)),
#  ((102, 70, 147, 172, 85),
#   (196, 92, 16, 205, 107),
#   (151, 74, 142, 83, 1),
#   (27, 138, 41, 15, 90),
#   (278, 39, 81, 141, 246),
#   (227, 206, 131, 133, 73),
#   (81, 219, 140, 93, 198),
#   (243, 108, 72, 178, 220),
#   (238, 136, 2, 5, 79),
#   (70, 129, 36, 29, 63),
#   (130, 184, 111, 26, 91),
#   (302, 221, 43, 7, 176),
#   (242, 110, 110, 59, 102),
#   (275, 1, 12, 93, 165),
#   (358, 82, 2, 228, 232),
#   (27, 25, 216, 224, 239),
#   (291, 170, 25, 141, 48),
#   (14, 41, 310, 274, 201),
#   (281, 77, 18, 243, 48),
#   (264, 236, 66, 64, 161)),
#  ((89, 18, 216, 142, 44),
#   (319, 27, 15, 34, 203),
#   (205, 83, 46, 260, 102),
#   (263, 177, 82, 153, 50),
#   (185, 124, 90, 0, 143),
#   (290, 106, 52, 123, 99),
#   (138, 58, 57, 73, 197),
#   (77, 203, 85, 26, 174),
#   (170, 23, 78, 135, 0),
#   (214, 147, 91, 123, 156),
#   (308, 103, 12, 235, 198),
#   (26, 9, 329, 179, 244),
#   (217, 191, 29, 148, 255),
#   (194, 199, 128, 118, 13),
#   (300, 62, 24, 262, 150),
#   (222, 121, 114, 2, 41),
#   (350, 113, 3, 17, 28),
#   (153, 133, 90, 106, 196),
#   (193, 175, 70, 110, 211),
#   (140, 46, 43, 292, 106)),
#  ((355, 62, 6, 76, 8),
#   (17, 157, 83, 57, 246),
#   (130, 65, 53, 9, 35),
#   (171, 177, 83, 24, 81),
#   (10, 93, 259, 206, 14),
#   (79, 9, 128, 165, 73),
#   (255, 171, 8, 188, 109),
#   (121, 71, 108, 234, 237),
#   (206, 107, 21, 209, 138),
#   (139, 128, 2, 51, 64),
#   (0, 16, 9, 163, 40),
#   (236, 217, 53, 77, 100),
#   (223, 135, 67, 85, 94),
#   (220, 67, 109, 185, 98),
#   (128, 57, 125, 181, 86),
#   (281, 30, 58, 13, 86),
#   (88, 61, 192, 85, 111),
#   (135, 76, 62, 109, 206),
#   (145, 150, 10, 102, 170),
#   (359, 58, 4, 234, 97)),
#  ((143, 240, 220, 98, 103),
#   (356, 202, 0, 18, 200),
#   (130, 166, 115, 102, 122),
#   (163, 125, 18, 39, 163),
#   (213, 76, 138, 193, 230),
#   (228, 60, 3, 64, 226),
#   (12, 149, 213, 110, 247),
#   (49, 91, 197, 182, 14),
#   (250, 239, 63, 66, 130),
#   (180, 133, 76, 215, 221),
#   (82, 31, 256, 11, 56),
#   (2, 13, 28, 68, 127),
#   (330, 103, 31, 249, 225),
#   (160, 152, 97, 185, 90),
#   (300, 11, 30, 53, 163),
#   (234, 82, 124, 258, 77),
#   (25, 52, 165, 58, 152),
#   (312, 22, 10, 26, 186),
#   (274, 240, 8, 96, 68),
#   (200, 99, 110, 144, 217)),
#  ((128, 120, 210, 173, 31),
#   (263, 158, 98, 144, 91),
#   (263, 213, 31, 65, 68),
#   (203, 72, 18, 188, 186),
#   (123, 142, 240, 117, 223),
#   (340, 209, 2, 21, 139),
#   (54, 178, 86, 75, 33),
#   (167, 95, 125, 44, 177),
#   (165, 147, 0, 109, 194),
#   (71, 19, 156, 254, 141),
#   (257, 40, 61, 98, 12),
#   (66, 55, 51, 21, 255),
#   (153, 132, 79, 3, 255),
#   (351, 0, 11, 318, 56),
#   (275, 70, 24, 239, 29),
#   (124, 70, 58, 58, 232),
#   (48, 177, 151, 39, 182),
#   (275, 55, 31, 220, 25),
#   (174, 16, 174, 318, 36),
#   (95, 189, 153, 24, 84)),
#  ((106, 60, 84, 246, 165),
#   (38, 79, 61, 5, 169),
#   (252, 107, 66, 110, 115),
#   (64, 86, 85, 59, 222),
#   (142, 181, 166, 69, 20),
#   (297, 116, 54, 202, 224),
#   (88, 109, 197, 163, 241),
#   (307, 138, 9, 0, 185),
#   (278, 35, 49, 235, 174),
#   (89, 228, 182, 11, 95),
#   (291, 233, 7, 12, 176),
#   (55, 49, 21, 73, 247),
#   (60, 221, 151, 122, 43),
#   (40, 228, 56, 7, 170),
#   (120, 46, 190, 161, 117),
#   (324, 155, 4, 168, 153),
#   (223, 78, 136, 29, 42),
#   (158, 201, 153, 12, 193),
#   (297, 218, 22, 124, 244),
#   (286, 30, 19, 306, 211)),
#  ((60, 38, 268, 84, 202),
#   (144, 170, 44, 141, 164),
#   (55, 59, 304, 284, 160),
#   (121, 119, 212, 92, 121),
#   (71, 74, 71, 43, 142),
#   (1, 40, 294, 147, 12),
#   (359, 167, 1, 54, 172),
#   (157, 87, 77, 38, 124),
#   (143, 185, 7, 70, 214),
#   (96, 47, 20, 286, 245),
#   (189, 24, 26, 84, 20),
#   (198, 67, 118, 89, 50),
#   (154, 143, 27, 118, 179),
#   (32, 208, 48, 73, 116),
#   (238, 67, 3, 8, 145),
#   (258, 116, 66, 171, 102),
#   (352, 158, 12, 80, 196),
#   (90, 16, 90, 163, 184),
#   (162, 194, 61, 29, 131),
#   (27, 36, 9, 132, 64)),
#  ((50, 72, 225, 188, 47),
#   (101, 106, 204, 81, 177),
#   (155, 123, 116, 10, 252),
#   (200, 171, 156, 77, 120),
#   (44, 136, 83, 162, 19),
#   (242, 68, 65, 67, 37),
#   (247, 148, 85, 197, 243),
#   (163, 218, 154, 115, 229),
#   (275, 7, 18, 35, 130),
#   (163, 165, 11, 176, 135),
#   (55, 53, 300, 2, 42),
#   (278, 113, 49, 24, 225),
#   (172, 145, 151, 4, 125),
#   (275, 235, 89, 22, 3),
#   (326, 93, 20, 7, 140),
#   (235, 3, 13, 266, 29),
#   (3, 100, 233, 256, 56),
#   (8, 146, 52, 197, 232),
#   (285, 130, 32, 217, 142),
#   (249, 147, 106, 208, 224)),
#  ((19, 148, 115, 88, 209),
#   (107, 17, 246, 320, 23),
#   (140, 175, 143, 104, 141),
#   (286, 165, 25, 112, 109),
#   (123, 128, 150, 215, 168),
#   (282, 32, 0, 270, 61),
#   (21, 158, 54, 44, 233),
#   (85, 94, 3, 163, 108),
#   (169, 40, 121, 105, 178),
#   (115, 118, 23, 21, 228),
#   (92, 173, 147, 156, 85),
#   (173, 196, 50, 127, 106),
#   (206, 163, 79, 143, 56),
#   (142, 185, 159, 95, 113),
#   (157, 106, 39, 81, 31),
#   (121, 240, 157, 110, 82),
#   (206, 30, 84, 190, 211),
#   (278, 189, 8, 96, 175),
#   (97, 33, 224, 53, 157),
#   (164, 126, 44, 190, 206)),
#  ((149, 94, 123, 235, 13),
#   (264, 183, 40, 173, 140),
#   (159, 202, 104, 150, 9),
#   (300, 39, 61, 284, 112),
#   (358, 181, 4, 138, 243),
#   (167, 154, 177, 10, 252),
#   (348, 195, 7, 100, 51),
#   (279, 140, 64, 40, 158),
#   (345, 15, 10, 242, 223),
#   (26, 62, 235, 155, 71),
#   (194, 43, 93, 91, 166),
#   (115, 149, 40, 147, 169),
#   (201, 195, 87, 31, 4),
#   (271, 114, 86, 190, 200),
#   (99, 202, 34, 69, 48),
#   (118, 141, 214, 31, 177),
#   (15, 24, 52, 331, 101),
#   (337, 57, 18, 212, 199),
#   (88, 68, 142, 51, 107),
#   (233, 60, 71, 105, 141)),
#  ((358, 1, 4, 38, 132),
#   (33, 208, 236, 56, 250),
#   (48, 137, 183, 168, 254),
#   (357, 213, 6, 112, 134),
#   (301, 42, 1, 58, 102),
#   (83, 121, 61, 230, 130),
#   (331, 113, 16, 140, 249),
#   (50, 149, 230, 174, 70),
#   (335, 68, 24, 267, 23),
#   (53, 203, 249, 99, 235),
#   (213, 31, 132, 164, 191),
#   (82, 194, 77, 95, 78),
#   (226, 229, 25, 30, 192),
#   (276, 8, 76, 75, 124),
#   (323, 233, 38, 79, 101),
#   (39, 152, 180, 5, 73),
#   (275, 19, 12, 166, 245),
#   (108, 52, 178, 100, 115),
#   (256, 135, 76, 65, 226),
#   (67, 74, 34, 171, 215)),
#  ((47, 63, 288, 181, 224),
#   (45, 20, 194, 299, 53),
#   (90, 157, 203, 115, 240),
#   (238, 221, 0, 15, 76),
#   (166, 157, 35, 154, 193),
#   (291, 11, 6, 28, 30),
#   (239, 119, 111, 146, 232),
#   (307, 127, 9, 134, 29),
#   (83, 94, 203, 64, 134),
#   (337, 20, 5, 124, 203),
#   (256, 202, 56, 147, 97),
#   (226, 157, 21, 142, 1),
#   (109, 222, 31, 33, 141),
#   (101, 64, 137, 24, 57),
#   (92, 24, 85, 42, 59),
#   (345, 12, 12, 115, 154),
#   (16, 99, 11, 38, 123),
#   (225, 240, 6, 0, 156),
#   (361, 93, 3, 250, 190),
#   (345, 86, 19, 128, 192)),
#  ((252, 194, 3, 10, 26),
#   (113, 184, 100, 80, 60),
#   (214, 8, 43, 176, 56),
#   (310, 146, 46, 54, 40),
#   (126, 161, 203, 132, 162),
#   (151, 72, 190, 292, 196),
#   (47, 178, 252, 32, 127),
#   (299, 50, 35, 49, 91),
#   (293, 180, 49, 133, 21),
#   (222, 143, 93, 118, 146),
#   (188, 3, 8, 125, 95),
#   (119, 84, 230, 17, 105),
#   (265, 80, 9, 127, 122),
#   (131, 215, 47, 7, 211),
#   (299, 217, 65, 45, 184),
#   (51, 231, 200, 93, 55),
#   (328, 190, 15, 22, 79),
#   (4, 232, 345, 113, 242),
#   (62, 23, 77, 220, 180),
#   (329, 91, 14, 126, 75)),
#  ((360, 39, 2, 265, 44),
#   (197, 196, 14, 75, 57),
#   (7, 131, 196, 97, 185),
#   (225, 114, 111, 236, 165),
#   (332, 90, 31, 167, 52),
#   (104, 63, 199, 58, 28),
#   (241, 106, 44, 218, 6),
#   (64, 219, 206, 65, 56),
#   (202, 132, 93, 92, 169),
#   (20, 154, 164, 184, 134),
#   (221, 141, 82, 59, 63),
#   (108, 75, 109, 222, 3),
#   (251, 38, 54, 150, 58),
#   (248, 204, 82, 140, 188),
#   (222, 53, 118, 96, 207),
#   (309, 126, 44, 216, 68),
#   (155, 107, 136, 249, 210),
#   (210, 17, 153, 8, 228),
#   (56, 236, 253, 65, 23),
#   (115, 133, 117, 184, 192)),
#  ((109, 137, 52, 60, 22),
#   (7, 136, 275, 192, 125),
#   (209, 7, 64, 318, 103),
#   (41, 123, 189, 63, 250),
#   (261, 9, 26, 318, 210),
#   (362, 143, 0, 133, 18),
#   (326, 209, 37, 46, 175),
#   (166, 230, 134, 127, 159),
#   (266, 2, 69, 58, 136),
#   (137, 128, 6, 47, 39),
#   (244, 243, 17, 21, 121),
#   (249, 52, 62, 96, 163),
#   (47, 154, 297, 137, 220),
#   (318, 243, 32, 96, 173),
#   (128, 127, 42, 201, 254),
#   (145, 39, 198, 239, 180),
#   (272, 210, 26, 150, 249),
#   (66, 71, 216, 192, 80),
#   (232, 108, 108, 81, 171),
#   (359, 85, 2, 265, 19)),
#  ((317, 109, 5, 52, 201),
#   (315, 232, 19, 105, 27),
#   (280, 92, 43, 3, 113),
#   (338, 122, 20, 212, 164),
#   (149, 68, 147, 31, 111),
#   (147, 31, 41, 320, 21),
#   (110, 212, 76, 139, 162),
#   (202, 202, 79, 100, 41),
#   (294, 170, 15, 140, 23),
#   (200, 73, 8, 29, 212),
#   (217, 147, 138, 186, 250),
#   (355, 226, 7, 92, 37),
#   (52, 199, 242, 74, 190),
#   (104, 123, 28, 155, 194),
#   (305, 182, 11, 164, 233),
#   (361, 21, 3, 174, 147),
#   (136, 11, 154, 326, 66),
#   (154, 189, 57, 89, 20),
#   (318, 111, 30, 111, 173),
#   (103, 2, 253, 317, 178)),
#  ((342, 58, 16, 128, 99),
#   (193, 188, 75, 116, 125),
#   (264, 200, 15, 42, 117),
#   (266, 190, 76, 44, 203),
#   (306, 102, 44, 59, 152),
#   (88, 190, 182, 9, 112),
#   (313, 116, 45, 27, 115),
#   (296, 190, 39, 63, 164),
#   (28, 78, 133, 258, 81),
#   (301, 54, 8, 82, 58),
#   (307, 13, 46, 128, 242),
#   (211, 115, 51, 5, 203),
#   (165, 193, 90, 5, 11),
#   (338, 22, 17, 19, 235),
#   (289, 158, 14, 161, 110),
#   (83, 123, 254, 161, 97),
#   (125, 11, 8, 220, 140),
#   (214, 63, 114, 52, 40),
#   (59, 112, 280, 202, 205),
#   (345, 245, 18, 8, 102)),
#  ((248, 14, 37, 220, 200),
#   (105, 189, 15, 93, 118),
#   (355, 21, 1, 176, 182),
#   (62, 178, 297, 27, 4),
#   (43, 4, 261, 229, 150),
#   (282, 40, 42, 229, 118),
#   (171, 68, 144, 140, 214),
#   (183, 177, 41, 36, 161),
#   (312, 191, 38, 18, 160),
#   (244, 191, 28, 79, 49),
#   (123, 133, 69, 86, 179),
#   (324, 90, 12, 149, 135),
#   (304, 216, 20, 39, 190),
#   (231, 138, 37, 194, 231),
#   (236, 159, 12, 28, 65),
#   (201, 191, 67, 0, 209),
#   (118, 183, 132, 67, 220),
#   (14, 89, 79, 187, 73),
#   (138, 238, 208, 52, 37),
#   (29, 169, 268, 65, 180)),
#  ((265, 92, 79, 268, 120),
#   (61, 7, 53, 327, 31),
#   (275, 32, 8, 302, 196),
#   (39, 175, 7, 18, 186),
#   (51, 85, 198, 231, 224),
#   (45, 158, 102, 137, 11),
#   (257, 116, 52, 246, 192),
#   (99, 99, 23, 226, 8),
#   (151, 31, 51, 327, 160),
#   (27, 103, 324, 206, 144),
#   (151, 110, 90, 99, 27),
#   (279, 242, 11, 75, 4),
#   (202, 245, 27, 10, 175),
#   (116, 162, 68, 47, 56),
#   (245, 235, 78, 64, 85),
#   (362, 168, 2, 170, 101),
#   (285, 32, 73, 173, 247),
#   (100, 36, 81, 313, 12),
#   (16, 95, 287, 186, 58),
#   (18, 72, 235, 247, 179)),
#  ((309, 74, 17, 52, 60),
#   (245, 55, 35, 247, 130),
#   (345, 175, 3, 122, 108),
#   (272, 25, 63, 255, 171),
#   (271, 120, 51, 18, 86),
#   (203, 79, 131, 133, 138),
#   (251, 183, 5, 68, 73),
#   (196, 116, 114, 172, 51),
#   (359, 208, 4, 132, 219),
#   (138, 96, 105, 66, 60),
#   (115, 67, 231, 3, 139),
#   (135, 66, 176, 34, 247),
#   (170, 139, 54, 106, 218),
#   (129, 32, 16, 285, 226),
#   (265, 21, 90, 82, 114),
#   (340, 119, 1, 122, 213),
#   (135, 180, 184, 0, 221),
#   (1, 26, 108, 43, 65),
#   (250, 50, 5, 116, 192),
#   (209, 237, 140, 81, 209)),
#  ((22, 64, 171, 10, 49),
#   (300, 195, 52, 168, 112),
#   (42, 148, 225, 184, 246),
#   (35, 245, 272, 101, 129),
#   (128, 196, 231, 46, 5),
#   (265, 121, 82, 36, 202),
#   (220, 201, 22, 35, 37),
#   (310, 188, 32, 106, 237),
#   (25, 35, 170, 326, 153),
#   (64, 69, 295, 269, 139),
#   (88, 153, 107, 76, 155),
#   (99, 202, 28, 143, 101),
#   (119, 188, 213, 45, 230),
#   (244, 180, 110, 34, 94),
#   (230, 28, 43, 138, 119),
#   (312, 58, 27, 154, 125),
#   (240, 196, 40, 92, 4),
#   (86, 134, 47, 127, 244),
#   (19, 116, 257, 71, 175),
#   (28, 1, 237, 70, 62)),
#  ((35, 95, 227, 262, 122),
#   (74, 224, 271, 55, 68),
#   (274, 117, 41, 135, 16),
#   (182, 174, 14, 155, 221),
#   (132, 126, 67, 222, 10),
#   (25, 64, 197, 224, 109),
#   (297, 245, 1, 18, 235),
#   (251, 244, 26, 77, 174),
#   (116, 116, 237, 23, 25),
#   (318, 210, 32, 122, 30),
#   (56, 221, 97, 48, 116),
#   (316, 200, 33, 15, 99),
#   (88, 9, 28, 52, 178),
#   (54, 187, 230, 59, 128),
#   (53, 115, 233, 33, 48),
#   (7, 126, 66, 165, 163),
#   (143, 223, 181, 1, 76),
#   (146, 139, 124, 158, 130),
#   (208, 58, 155, 35, 156),
#   (222, 83, 27, 197, 183)),
#  ((94, 30, 40, 240, 114),
#   (0, 133, 293, 207, 36),
#   (26, 34, 161, 211, 55),
#   (134, 211, 199, 143, 5),
#   (159, 155, 143, 60, 57),
#   (201, 238, 159, 78, 92),
#   (322, 41, 5, 20, 147),
#   (205, 115, 152, 94, 40),
#   (122, 223, 78, 65, 147),
#   (233, 169, 107, 112, 35),
#   (328, 114, 6, 24, 185),
#   (299, 120, 58, 172, 10),
#   (205, 148, 101, 2, 31),
#   (135, 138, 78, 34, 177),
#   (57, 156, 116, 151, 32),
#   (230, 180, 131, 136, 60),
#   (330, 77, 5, 5, 83),
#   (26, 193, 133, 162, 125),
#   (256, 69, 57, 211, 45),
#   (51, 219, 115, 37, 170)),
#  ((49, 114, 87, 225, 55),
#   (276, 199, 49, 35, 134),
#   (191, 152, 43, 29, 68),
#   (309, 187, 22, 138, 163),
#   (22, 200, 322, 5, 217),
#   (324, 127, 16, 141, 181),
#   (48, 158, 62, 164, 124),
#   (123, 205, 183, 82, 8),
#   (248, 210, 71, 14, 169),
#   (50, 150, 164, 167, 172),
#   (187, 0, 55, 208, 208),
#   (173, 75, 65, 13, 124),
#   (13, 126, 226, 94, 76),
#   (75, 64, 187, 227, 10),
#   (63, 140, 47, 34, 147),
#   (96, 44, 157, 80, 89),
#   (244, 53, 40, 151, 37),
#   (145, 45, 119, 172, 223),
#   (20, 140, 108, 41, 89),
#   (343, 103, 21, 251, 149)),
#  ((91, 206, 253, 153, 226),
#   (329, 20, 29, 155, 24),
#   (68, 24, 291, 27, 132),
#   (165, 43, 116, 208, 65),
#   (67, 35, 200, 237, 1),
#   (249, 114, 48, 144, 51),
#   (92, 75, 252, 269, 160),
#   (199, 44, 157, 126, 217),
#   (45, 170, 33, 149, 145),
#   (261, 187, 56, 99, 194),
#   (308, 55, 16, 24, 165),
#   (171, 232, 186, 30, 252),
#   (174, 207, 185, 107, 167),
#   (185, 80, 29, 255, 204),
#   (230, 152, 77, 11, 194),
#   (112, 112, 101, 244, 45),
#   (266, 53, 12, 258, 51),
#   (212, 92, 147, 208, 49),
#   (249, 168, 101, 194, 75),
#   (286, 26, 51, 291, 21))]

# %% [markdown]
# Para poder seleccionar los mejores inidividuos de la población, necesitamos definir una función fitness. En este caso la función fitness se define como la suma de las diferencias (en valor absoluto) pixel a pixel entre la matriz que representa el individuo y la matriz que representa la imagen original.

# %%
def fitness_1(ind):
    return np.sum(np.absolute(decodifica(ind) - IM2ARRAY))

# %%
# Ejemplo:
fitness_1(ind_1)
# Out:
# 144572897775823

# %% [markdown]
# A continuación implementamos la selección por torneo. Para evitar repetir cálculos, cuando calculemos la función fitness de un individuo, la guardaremos en un diccionario y miraremos si ya ha sido calculada antes cuando necesitemos saber su valor. Las claves del diccionario serán los individuos y su valor, el valor de la función *fitness* que le corresponda.

# %% [markdown]
# ### Ejercicio 4
# Define la función *selecciona_uno_por_torneo(poblacion,dic)* que tome como entrada una población de individuos y un diccionario de pares *individuo:fitness* y devuelva una tupla *(seleccionado,nuevo_dic)* donde seleccionado sea un individuo de la población seleccionado por torneo con *NUM_PARTICIPANTES* como el número de participantes en cada torneo y *nuevo_dic* sea el diccionario *dic* al que se le han añadido los pares *individuo:fitness* que se hayan calculado en la búsqueda de *seleccionado*.

# %%
# Solución:

NUM_PARTICIPANTES = 4

def selecciona_uno_por_torneo(poblacion, dic):
    #num_participantes = random.randint(1, len(poblacion))
    participantes = random.sample(poblacion, NUM_PARTICIPANTES)
    nuevo_dic = dic.copy()
    max_cand = participantes[0]
    for ind in participantes:
        if not ind in nuevo_dic:
            nuevo_dic[ind] = fitness_1(ind)
        if nuevo_dic[ind] > nuevo_dic[max_cand]:
            max_cand = ind

    return max_cand, nuevo_dic

# %%
# Ejemplo de uso
# selecciona_uno_por_torneo(poblacion_inicial(),{},fitness_1)
# participantes = [random.choice(poblacion_inicial(3, 50, im2array_shape)) for _ in range(3)]

selecciona_uno_por_torneo(poblacion_inicial(7, 50, im2array_shape),{})
# Out:
# (((279, 54, 6, 90, 202),
#   (48, 156, 34, 145, 225),
#   (248, 175, 15, 4, 110),
#   (289, 107, 40, 203, 131),
#   (21, 11, 259, 336, 73),
#   (169, 185, 85, 100, 37),
#   (273, 20, 83, 222, 61),
#   (145, 218, 124, 3, 117),
#   (202, 134, 28, 59, 201),
#   (178, 157, 141, 168, 118),
#   (273, 107, 49, 8, 216),
#   (56, 21, 145, 83, 166),
#   (229, 119, 116, 16, 101),
#   (318, 1, 11, 48, 92),
#   (209, 181, 41, 31, 14),
#   (127, 223, 109, 19, 203),
#   (344, 22, 0, 177, 96),
#   (340, 0, 18, 228, 88),
#   (158, 65, 152, 70, 192),
#   (35, 6, 2, 267, 33),
#   (59, 187, 37, 137, 194),
#   (96, 216, 142, 0, 181),
#   (250, 85, 96, 64, 84),
#   (319, 114, 8, 166, 14),
#   (356, 181, 0, 146, 124),
#   (2, 10, 140, 230, 175),
#   (281, 116, 38, 92, 54),
#   (187, 6, 172, 44, 23),
#   (106, 13, 256, 176, 254),
#   (7, 2, 171, 183, 62),
#   (156, 94, 174, 113, 108),
#   (203, 131, 90, 29, 8),
#   (91, 111, 217, 199, 91),
#   (314, 153, 20, 49, 100),
#   (302, 121, 29, 68, 86),
#   (93, 188, 171, 25, 28),
#   (85, 242, 272, 29, 172),
#   (350, 193, 0, 69, 152),
#   (288, 73, 73, 212, 134),
#   (90, 133, 136, 32, 172),
#   (286, 33, 13, 131, 230),
#   (20, 215, 49, 147, 196),
#   (265, 237, 65, 69, 88),
#   (95, 188, 161, 6, 190),
#   (316, 112, 48, 214, 142),
#   (92, 182, 129, 154, 57),
#   (29, 161, 24, 102, 82),
#   (285, 32, 65, 169, 61),
#   (364, 67, 0, 238, 149),
#   (96, 129, 231, 22, 91)),
#  {((135, 111, 41, 25, 220),
#    (266, 79, 21, 269, 164),
#    (353, 35, 10, 308, 6),
#    (230, 48, 106, 190, 2),
#    (262, 100, 24, 77, 223),
#    (53, 190, 106, 153, 123),
#    (49, 115, 30, 213, 12),
#    (321, 6, 22, 71, 100),
#    (84, 82, 117, 198, 123),
#    (150, 138, 46, 58, 71),
#    (100, 183, 235, 117, 230),
#    (25, 220, 174, 10, 19),
#    (170, 98, 69, 213, 53),
#    (110, 62, 196, 195, 83),
#    (5, 75, 179, 93, 0),
#    (336, 93, 18, 44, 96),
#    (157, 98, 109, 36, 145),
#    (155, 145, 116, 97, 56),
#    (262, 151, 2, 60, 149),
#    (58, 151, 36, 30, 153),
#    (93, 82, 3, 86, 112),
#    (201, 142, 10, 97, 140),
#    (165, 96, 21, 4, 45),
#    (328, 149, 27, 34, 199),
#    (285, 138, 63, 169, 216),
#    (229, 188, 116, 89, 202),
#    (202, 218, 65, 120, 216),
#    (90, 63, 71, 27, 200),
#    (326, 235, 10, 121, 24),
#    (111, 212, 128, 2, 38),
#    (89, 239, 255, 105, 119),
#    (66, 134, 257, 222, 140),
#    (246, 61, 41, 120, 7),
#    (4, 69, 285, 143, 66),
#    (15, 237, 233, 100, 108),
#    (296, 164, 25, 181, 113),
#    (350, 95, 4, 12, 219),
#    (238, 156, 9, 104, 80),
#    (98, 205, 242, 81, 196),
#    (291, 181, 2, 170, 72),
#    (136, 219, 221, 64, 44),
#    (100, 109, 133, 71, 64),
#    (260, 64, 17, 256, 247),
#    (249, 16, 30, 69, 147),
#    (200, 12, 15, 92, 180),
#    (287, 219, 73, 68, 143),
#    (226, 181, 13, 26, 217),
#    (150, 228, 121, 127, 244),
#    (275, 20, 21, 206, 252),
#    (198, 27, 150, 174, 231)): 268448340045799,
#   ((325, 22, 7, 245, 218),
#    (108, 158, 255, 97, 161),
#    (179, 233, 73, 46, 76),
#    (63, 51, 73, 272, 112),
#    (117, 238, 71, 45, 253),
#    (138, 210, 222, 43, 27),
#    (308, 92, 50, 252, 230),
#    (164, 143, 136, 201, 245),
#    (55, 189, 276, 49, 64),
#    (125, 203, 198, 19, 97),
#    (152, 132, 198, 25, 224),
#    (28, 20, 63, 9, 79),
#    (287, 5, 55, 103, 44),
#    (39, 93, 222, 170, 22),
#    (46, 74, 285, 139, 194),
#    (295, 41, 45, 218, 56),
#    (304, 57, 6, 2, 189),
#    (91, 234, 258, 61, 127),
#    (226, 138, 136, 181, 47),
#    (38, 68, 149, 86, 222),
#    (343, 59, 0, 173, 119),
#    (23, 26, 224, 184, 48),
#    (142, 196, 98, 70, 159),
#    (199, 175, 68, 39, 237),
#    (62, 36, 255, 280, 58),
#    (176, 146, 65, 90, 210),
#    (225, 170, 133, 144, 9),
#    (37, 214, 318, 12, 216),
#    (158, 30, 201, 148, 150),
#    (337, 62, 15, 207, 132),
#    (346, 6, 13, 280, 2),
#    (94, 181, 232, 122, 125),
#    (348, 71, 14, 182, 2),
#    (269, 24, 31, 127, 238),
#    (327, 63, 13, 40, 173),
#    (303, 168, 45, 150, 209),
#    (13, 188, 293, 153, 125),
#    (335, 6, 5, 287, 70),
#    (61, 212, 120, 44, 131),
#    (252, 233, 13, 9, 220),
#    (80, 116, 190, 132, 102),
#    (354, 148, 8, 92, 146),
#    (328, 142, 17, 79, 211),
#    (256, 67, 56, 48, 246),
#    (127, 60, 107, 21, 227),
#    (237, 188, 67, 159, 29),
#    (126, 80, 198, 115, 231),
#    (232, 40, 76, 38, 192),
#    (254, 114, 6, 175, 225),
#    (48, 35, 257, 268, 241)): 322418896623679,
#   ((74, 115, 34, 203, 57),
#    (261, 139, 36, 109, 219),
#    (129, 145, 73, 193, 23),
#    (271, 153, 89, 68, 187),
#    (94, 172, 175, 78, 171),
#    (276, 58, 23, 219, 76),
#    (16, 41, 187, 170, 222),
#    (223, 13, 40, 30, 210),
#    (347, 120, 0, 175, 64),
#    (164, 145, 115, 86, 194),
#    (216, 172, 68, 62, 161),
#    (229, 11, 26, 149, 70),
#    (48, 124, 51, 49, 209),
#    (9, 163, 227, 88, 145),
#    (272, 188, 0, 61, 216),
#    (189, 78, 77, 286, 118),
#    (328, 166, 23, 107, 244),
#    (218, 229, 97, 14, 43),
#    (107, 212, 79, 149, 20),
#    (116, 66, 79, 287, 211),
#    (138, 191, 220, 139, 45),
#    (17, 193, 173, 36, 249),
#    (4, 181, 4, 68, 227),
#    (309, 13, 10, 304, 66),
#    (230, 240, 37, 2, 168),
#    (45, 115, 279, 138, 249),
#    (76, 26, 61, 167, 63),
#    (259, 3, 2, 126, 52),
#    (29, 55, 194, 108, 11),
#    (127, 205, 21, 124, 215),
#    (214, 55, 64, 20, 49),
#    (124, 9, 120, 35, 153),
#    (254, 53, 94, 212, 97),
#    (119, 123, 186, 44, 22),
#    (289, 90, 23, 204, 175),
#    (328, 203, 29, 68, 115),
#    (264, 103, 75, 180, 234),
#    (222, 97, 23, 12, 67),
#    (231, 158, 5, 182, 246),
#    (33, 32, 0, 226, 148),
#    (161, 197, 112, 8, 100),
#    (277, 202, 5, 108, 221),
#    (306, 22, 0, 72, 170),
#    (263, 214, 93, 12, 75),
#    (244, 184, 112, 120, 2),
#    (189, 124, 164, 16, 91),
#    (144, 90, 111, 216, 235),
#    (253, 88, 32, 173, 139),
#    (15, 75, 215, 50, 181),
#    (321, 229, 9, 14, 0)): 261937169705561,
#   ((279, 54, 6, 90, 202),
#    (48, 156, 34, 145, 225),
#    (248, 175, 15, 4, 110),
#    (289, 107, 40, 203, 131),
#    (21, 11, 259, 336, 73),
#    (169, 185, 85, 100, 37),
#    (273, 20, 83, 222, 61),
#    (145, 218, 124, 3, 117),
#    (202, 134, 28, 59, 201),
#    (178, 157, 141, 168, 118),
#    (273, 107, 49, 8, 216),
#    (56, 21, 145, 83, 166),
#    (229, 119, 116, 16, 101),
#    (318, 1, 11, 48, 92),
#    (209, 181, 41, 31, 14),
#    (127, 223, 109, 19, 203),
#    (344, 22, 0, 177, 96),
#    (340, 0, 18, 228, 88),
#    (158, 65, 152, 70, 192),
#    (35, 6, 2, 267, 33),
#    (59, 187, 37, 137, 194),
#    (96, 216, 142, 0, 181),
#    (250, 85, 96, 64, 84),
#    (319, 114, 8, 166, 14),
#    (356, 181, 0, 146, 124),
#    (2, 10, 140, 230, 175),
#    (281, 116, 38, 92, 54),
#    (187, 6, 172, 44, 23),
#    (106, 13, 256, 176, 254),
#    (7, 2, 171, 183, 62),
#    (156, 94, 174, 113, 108),
#    (203, 131, 90, 29, 8),
#    (91, 111, 217, 199, 91),
#    (314, 153, 20, 49, 100),
#    (302, 121, 29, 68, 86),
#    (93, 188, 171, 25, 28),
#    (85, 242, 272, 29, 172),
#    (350, 193, 0, 69, 152),
#    (288, 73, 73, 212, 134),
#    (90, 133, 136, 32, 172),
#    (286, 33, 13, 131, 230),
#    (20, 215, 49, 147, 196),
#    (265, 237, 65, 69, 88),
#    (95, 188, 161, 6, 190),
#    (316, 112, 48, 214, 142),
#    (92, 182, 129, 154, 57),
#    (29, 161, 24, 102, 82),
#    (285, 32, 65, 169, 61),
#    (364, 67, 0, 238, 149),
#    (96, 129, 231, 22, 91)): 355855214525823})

# %% [markdown]
# ### Ejercicio 5
# Define la función *seleccion_por_torneo(poblacion,num_seleccionados,dic)* que además de la población y el diccionario del ejercicio anterior toem el número de individuos que queremos seleccionar. La salida debe ser una tupla *(seleccion,nuevo_dic)* donde *nuevo_dic* es el diccionario actualizado y sleccion una lista de individuos seleccionados.

# %%
# Solución:

def seleccion_por_torneo(poblacion, num_seleccionados, dic):
    nuevo_dic = dic.copy()
    seleccion = []
    
    for _ in range(num_seleccionados):
        sel_torneo = selecciona_uno_por_torneo(poblacion, nuevo_dic)

        nuevo_dic = sel_torneo[1]
            
        seleccion.append(sel_torneo[0])

    return seleccion, nuevo_dic

# %%
# Ejemplo de uso
seleccion_por_torneo(poblacion_inicial(7, 50, im2array_shape),4,{})
# Out:
# ([((308, 195, 34, 69, 14),
#    (276, 42, 30, 283, 106),
#    (17, 41, 305, 101, 139),
#    (88, 56, 151, 30, 36),
#    (43, 212, 140, 77, 224),
#    (347, 78, 3, 172, 59),
#    (133, 169, 7, 101, 126),
#    (278, 84, 10, 137, 56),
#    (160, 76, 69, 107, 235),
#    (46, 39, 216, 243, 42),
#    (179, 82, 165, 73, 133),
#    (98, 225, 191, 65, 122),
#    (157, 156, 41, 186, 65),
#    (131, 72, 117, 158, 168),
#    (236, 164, 49, 160, 35),
#    (123, 193, 23, 46, 22),
#    (209, 41, 41, 128, 122),
#    (172, 236, 51, 118, 0),
#    (75, 15, 219, 316, 209),
#    (3, 206, 48, 55, 210),
#    (341, 196, 12, 102, 76),
#    (140, 183, 125, 179, 72),
#    (124, 198, 168, 73, 176),
#    (243, 226, 33, 50, 240),
#    (53, 114, 302, 232, 8),
#    (239, 85, 5, 17, 242),
#    (11, 95, 118, 86, 38),
#    (325, 150, 22, 165, 37),
#    (196, 105, 76, 60, 99),
#    (16, 230, 290, 134, 196),
#    (47, 61, 109, 283, 144),
#    (73, 79, 61, 177, 10),
#    (70, 178, 287, 172, 133),
#    (49, 221, 234, 53, 176),
#    (304, 216, 7, 122, 166),
#    (329, 49, 34, 261, 89),
#    (113, 58, 129, 291, 236),
#    (86, 35, 200, 159, 183),
#    (9, 205, 57, 2, 84),
#    (364, 242, 0, 110, 88),
#    (336, 124, 15, 93, 35),
#    (92, 15, 220, 93, 199),
#    (329, 129, 25, 14, 231),
#    (169, 17, 22, 182, 46),
#    (66, 130, 128, 219, 35),
#    (298, 47, 10, 234, 92),
#    (144, 231, 182, 64, 199),
#    (42, 127, 180, 145, 75),
#    (98, 9, 137, 261, 30),
#    (163, 124, 146, 112, 158)),
#   ((84, 142, 209, 159, 49),
#    (111, 119, 137, 111, 49),
#    (240, 245, 62, 118, 248),
#    (295, 167, 53, 117, 238),
#    (144, 240, 113, 42, 135),
#    (9, 63, 355, 265, 152),
#    (96, 27, 248, 301, 119),
#    (311, 109, 0, 149, 51),
#    (238, 59, 33, 109, 225),
#    (324, 118, 2, 202, 79),
#    (179, 90, 18, 274, 187),
#    (135, 104, 4, 67, 237),
#    (278, 189, 44, 32, 196),
#    (349, 102, 12, 145, 34),
#    (43, 132, 44, 140, 79),
#    (118, 244, 138, 8, 224),
#    (24, 39, 299, 318, 47),
#    (72, 49, 22, 62, 87),
#    (227, 181, 58, 112, 117),
#    (166, 53, 132, 47, 46),
#    (206, 123, 118, 77, 172),
#    (110, 139, 108, 31, 6),
#    (338, 162, 26, 35, 122),
#    (286, 81, 61, 18, 103),
#    (69, 109, 69, 33, 26),
#    (86, 103, 277, 149, 162),
#    (4, 66, 332, 107, 99),
#    (103, 99, 243, 36, 241),
#    (188, 211, 149, 105, 237),
#    (345, 203, 13, 76, 145),
#    (6, 40, 253, 279, 87),
#    (87, 162, 35, 181, 136),
#    (160, 206, 62, 22, 179),
#    (44, 134, 237, 54, 10),
#    (290, 39, 42, 152, 252),
#    (171, 229, 180, 39, 43),
#    (193, 184, 113, 100, 135),
#    (55, 134, 60, 122, 74),
#    (93, 211, 45, 111, 175),
#    (12, 98, 259, 26, 205),
#    (63, 209, 166, 52, 22),
#    (134, 47, 156, 220, 125),
#    (70, 227, 268, 109, 154),
#    (48, 27, 146, 210, 179),
#    (259, 23, 20, 303, 231),
#    (129, 144, 0, 179, 220),
#    (176, 220, 67, 144, 96),
#    (20, 106, 186, 256, 195),
#    (187, 123, 113, 85, 130),
#    (16, 139, 73, 118, 197)),
#   ((84, 142, 209, 159, 49),
#    (111, 119, 137, 111, 49),
#    (240, 245, 62, 118, 248),
#    (295, 167, 53, 117, 238),
#    (144, 240, 113, 42, 135),
#    (9, 63, 355, 265, 152),
#    (96, 27, 248, 301, 119),
#    (311, 109, 0, 149, 51),
#    (238, 59, 33, 109, 225),
#    (324, 118, 2, 202, 79),
#    (179, 90, 18, 274, 187),
#    (135, 104, 4, 67, 237),
#    (278, 189, 44, 32, 196),
#    (349, 102, 12, 145, 34),
#    (43, 132, 44, 140, 79),
#    (118, 244, 138, 8, 224),
#    (24, 39, 299, 318, 47),
#    (72, 49, 22, 62, 87),
#    (227, 181, 58, 112, 117),
#    (166, 53, 132, 47, 46),
#    (206, 123, 118, 77, 172),
#    (110, 139, 108, 31, 6),
#    (338, 162, 26, 35, 122),
#    (286, 81, 61, 18, 103),
#    (69, 109, 69, 33, 26),
#    (86, 103, 277, 149, 162),
#    (4, 66, 332, 107, 99),
#    (103, 99, 243, 36, 241),
#    (188, 211, 149, 105, 237),
#    (345, 203, 13, 76, 145),
#    (6, 40, 253, 279, 87),
#    (87, 162, 35, 181, 136),
#    (160, 206, 62, 22, 179),
#    (44, 134, 237, 54, 10),
#    (290, 39, 42, 152, 252),
#    (171, 229, 180, 39, 43),
#    (193, 184, 113, 100, 135),
#    (55, 134, 60, 122, 74),
#    (93, 211, 45, 111, 175),
#    (12, 98, 259, 26, 205),
#    (63, 209, 166, 52, 22),
#    (134, 47, 156, 220, 125),
#    (70, 227, 268, 109, 154),
#    (48, 27, 146, 210, 179),
#    (259, 23, 20, 303, 231),
#    (129, 144, 0, 179, 220),
#    (176, 220, 67, 144, 96),
#    (20, 106, 186, 256, 195),
#    (187, 123, 113, 85, 130),
#    (16, 139, 73, 118, 197)),
#   ((248, 12, 21, 238, 205),
#    (141, 96, 16, 191, 179),
#    (278, 141, 27, 41, 238),
#    (262, 182, 93, 9, 234),
#    (218, 6, 135, 72, 21),
#    (312, 64, 26, 196, 90),
#    (316, 238, 44, 122, 47),
#    (97, 142, 55, 24, 198),
#    (223, 41, 113, 269, 8),
#    (143, 25, 199, 310, 230),
#    (173, 177, 106, 177, 98),
#    (149, 64, 3, 248, 237),
#    (40, 91, 274, 194, 25),
#    (61, 224, 116, 58, 76),
#    (285, 86, 55, 57, 166),
#    (357, 181, 1, 33, 69),
#    (341, 187, 15, 154, 74),
#    (225, 230, 128, 29, 75),
#    (318, 12, 28, 57, 26),
#    (250, 2, 64, 326, 63),
#    (140, 89, 137, 132, 63),
#    (148, 173, 106, 163, 66),
#    (195, 119, 76, 15, 208),
#    (102, 196, 238, 20, 202),
#    (76, 115, 270, 118, 70),
#    (252, 238, 18, 58, 77),
#    (162, 42, 109, 242, 116),
#    (86, 214, 128, 135, 230),
#    (194, 48, 10, 19, 54),
#    (115, 126, 158, 189, 62),
#    (58, 140, 250, 22, 182),
#    (311, 81, 0, 169, 22),
#    (311, 139, 37, 113, 50),
#    (231, 63, 87, 121, 7),
#    (136, 94, 125, 200, 49),
#    (9, 64, 218, 96, 109),
#    (79, 160, 73, 114, 177),
#    (164, 7, 147, 85, 141),
#    (172, 206, 51, 22, 152),
#    (228, 99, 48, 16, 186),
#    (334, 171, 8, 136, 118),
#    (1, 197, 21, 119, 180),
#    (114, 101, 72, 231, 58),
#    (353, 148, 6, 22, 64),
#    (57, 134, 190, 86, 193),
#    (100, 16, 215, 173, 66),
#    (246, 45, 29, 7, 119),
#    (264, 51, 19, 68, 152),
#    (297, 220, 45, 89, 127),
#    (284, 154, 30, 93, 179))],
#  {((308, 195, 34, 69, 14),
#    (276, 42, 30, 283, 106),
#    (17, 41, 305, 101, 139),
#    (88, 56, 151, 30, 36),
#    (43, 212, 140, 77, 224),
#    (347, 78, 3, 172, 59),
#    (133, 169, 7, 101, 126),
#    (278, 84, 10, 137, 56),
#    (160, 76, 69, 107, 235),
#    (46, 39, 216, 243, 42),
#    (179, 82, 165, 73, 133),
#    (98, 225, 191, 65, 122),
#    (157, 156, 41, 186, 65),
#    (131, 72, 117, 158, 168),
#    (236, 164, 49, 160, 35),
#    (123, 193, 23, 46, 22),
#    (209, 41, 41, 128, 122),
#    (172, 236, 51, 118, 0),
#    (75, 15, 219, 316, 209),
#    (3, 206, 48, 55, 210),
#    (341, 196, 12, 102, 76),
#    (140, 183, 125, 179, 72),
#    (124, 198, 168, 73, 176),
#    (243, 226, 33, 50, 240),
#    (53, 114, 302, 232, 8),
#    (239, 85, 5, 17, 242),
#    (11, 95, 118, 86, 38),
#    (325, 150, 22, 165, 37),
#    (196, 105, 76, 60, 99),
#    (16, 230, 290, 134, 196),
#    (47, 61, 109, 283, 144),
#    (73, 79, 61, 177, 10),
#    (70, 178, 287, 172, 133),
#    (49, 221, 234, 53, 176),
#    (304, 216, 7, 122, 166),
#    (329, 49, 34, 261, 89),
#    (113, 58, 129, 291, 236),
#    (86, 35, 200, 159, 183),
#    (9, 205, 57, 2, 84),
#    (364, 242, 0, 110, 88),
#    (336, 124, 15, 93, 35),
#    (92, 15, 220, 93, 199),
#    (329, 129, 25, 14, 231),
#    (169, 17, 22, 182, 46),
#    (66, 130, 128, 219, 35),
#    (298, 47, 10, 234, 92),
#    (144, 231, 182, 64, 199),
#    (42, 127, 180, 145, 75),
#    (98, 9, 137, 261, 30),
#    (163, 124, 146, 112, 158)): 295609711303989,
#   ((351, 79, 8, 265, 60),
#    (10, 35, 21, 143, 156),
#    (293, 112, 69, 9, 49),
#    (107, 167, 196, 17, 194),
#    (333, 117, 21, 217, 158),
#    (359, 52, 2, 99, 85),
#    (192, 68, 34, 242, 232),
#    (82, 119, 243, 201, 90),
#    (70, 116, 204, 194, 109),
#    (310, 146, 28, 41, 54),
#    (52, 224, 56, 111, 59),
#    (239, 91, 116, 169, 177),
#    (290, 240, 64, 102, 198),
#    (192, 105, 126, 210, 73),
#    (326, 64, 4, 21, 151),
#    (181, 116, 122, 53, 122),
#    (152, 218, 78, 78, 28),
#    (26, 64, 227, 48, 161),
#    (208, 185, 35, 179, 157),
#    (32, 172, 163, 61, 52),
#    (291, 44, 20, 276, 249),
#    (349, 149, 10, 130, 144),
#    (25, 0, 231, 98, 35),
#    (141, 20, 70, 231, 74),
#    (302, 231, 21, 86, 45),
#    (113, 146, 230, 215, 207),
#    (38, 132, 73, 17, 11),
#    (286, 99, 20, 13, 90),
#    (324, 234, 33, 35, 184),
#    (141, 97, 134, 97, 193),
#    (26, 238, 139, 122, 150),
#    (76, 213, 90, 117, 118),
#    (287, 137, 28, 133, 127),
#    (287, 169, 16, 150, 160),
#    (122, 112, 141, 35, 206),
#    (203, 173, 107, 109, 231),
#    (293, 160, 61, 43, 35),
#    (269, 144, 15, 170, 237),
#    (132, 78, 155, 173, 147),
#    (57, 168, 85, 81, 211),
#    (13, 116, 172, 43, 81),
#    (226, 93, 66, 241, 0),
#    (48, 30, 0, 172, 210),
#    (120, 185, 24, 143, 2),
#    (298, 210, 64, 117, 105),
#    (189, 60, 107, 264, 99),
#    (37, 10, 109, 43, 104),
#    (292, 168, 22, 75, 58),
#    (25, 215, 289, 15, 81),
#    (347, 239, 1, 113, 67)): 293994804262984,
#   ((310, 193, 25, 171, 22),
#    (14, 111, 153, 37, 204),
#    (6, 58, 321, 304, 129),
#    (122, 188, 109, 121, 28),
#    (235, 24, 55, 262, 75),
#    (252, 106, 81, 98, 37),
#    (268, 21, 73, 219, 107),
#    (298, 182, 31, 133, 76),
#    (154, 12, 182, 333, 190),
#    (162, 195, 172, 165, 139),
#    (229, 11, 119, 146, 55),
#    (59, 134, 275, 155, 28),
#    (186, 184, 47, 6, 165),
#    (353, 195, 4, 148, 15),
#    (228, 102, 66, 186, 76),
#    (132, 54, 99, 44, 145),
#    (85, 101, 238, 221, 78),
#    (217, 33, 121, 158, 73),
#    (96, 16, 89, 237, 165),
#    (137, 217, 40, 16, 115),
#    (180, 202, 167, 64, 241),
#    (342, 95, 7, 148, 29),
#    (185, 179, 50, 138, 28),
#    (87, 122, 118, 77, 126),
#    (310, 112, 22, 126, 227),
#    (38, 51, 58, 233, 248),
#    (189, 24, 132, 268, 123),
#    (69, 155, 293, 105, 18),
#    (364, 223, 0, 80, 195),
#    (149, 50, 99, 47, 139),
#    (98, 133, 0, 218, 233),
#    (313, 180, 11, 116, 239),
#    (353, 109, 10, 28, 4),
#    (335, 93, 8, 263, 56),
#    (44, 245, 140, 16, 74),
#    (294, 239, 63, 93, 228),
#    (81, 154, 119, 198, 19),
#    (120, 198, 114, 42, 138),
#    (54, 47, 7, 213, 243),
#    (152, 104, 9, 184, 50),
#    (213, 232, 137, 9, 230),
#    (318, 94, 28, 229, 165),
#    (56, 193, 114, 61, 54),
#    (328, 76, 9, 278, 215),
#    (184, 159, 15, 83, 31),
#    (248, 21, 72, 323, 202),
#    (98, 104, 206, 112, 182),
#    (154, 156, 158, 185, 191),
#    (94, 202, 179, 77, 169),
#    (281, 171, 13, 2, 233)): 282900904069937,
#   ((72, 166, 5, 49, 41),
#    (119, 142, 75, 149, 161),
#    (225, 133, 29, 84, 51),
#    (136, 149, 155, 178, 44),
#    (230, 93, 54, 212, 51),
#    (57, 16, 216, 154, 250),
#    (19, 219, 41, 36, 87),
#    (267, 197, 33, 135, 192),
#    (122, 44, 141, 19, 62),
#    (19, 224, 328, 106, 23),
#    (224, 122, 77, 39, 80),
#    (282, 190, 61, 129, 100),
#    (122, 195, 167, 99, 50),
#    (226, 6, 41, 135, 226),
#    (208, 188, 108, 110, 33),
#    (283, 114, 61, 228, 98),
#    (177, 169, 137, 189, 74),
#    (300, 45, 41, 248, 191),
#    (133, 22, 22, 74, 89),
#    (213, 7, 37, 110, 165),
#    (192, 8, 158, 93, 97),
#    (216, 154, 144, 125, 207),
#    (249, 107, 76, 175, 188),
#    (333, 181, 11, 28, 202),
#    (59, 154, 77, 128, 227),
#    (86, 153, 23, 76, 135),
#    (61, 96, 230, 76, 18),
#    (87, 88, 172, 230, 19),
#    (15, 231, 82, 46, 202),
#    (142, 76, 48, 74, 93),
#    (289, 136, 20, 196, 20),
#    (118, 172, 224, 54, 60),
#    (83, 175, 47, 95, 145),
#    (148, 144, 24, 86, 134),
#    (113, 214, 132, 62, 191),
#    (360, 106, 3, 82, 237),
#    (147, 76, 215, 26, 167),
#    (153, 79, 19, 221, 17),
#    (288, 18, 54, 287, 192),
#    (139, 100, 132, 220, 196),
#    (187, 105, 174, 19, 9),
#    (325, 40, 5, 210, 192),
#    (173, 36, 30, 139, 94),
#    (334, 67, 29, 208, 162),
#    (285, 109, 42, 149, 203),
#    (319, 3, 21, 89, 84),
#    (99, 201, 161, 131, 35),
#    (261, 165, 41, 53, 181),
#    (166, 99, 31, 192, 64),
#    (146, 57, 98, 134, 191)): 244297740087871,
#   ((152, 34, 77, 15, 163),
#    (147, 99, 152, 38, 54),
#    (331, 44, 9, 127, 72),
#    (283, 16, 56, 236, 240),
#    (345, 7, 13, 104, 118),
#    (143, 215, 175, 58, 97),
#    (326, 203, 26, 39, 214),
#    (144, 173, 44, 160, 253),
#    (209, 217, 15, 67, 234),
#    (315, 32, 26, 266, 114),
#    (235, 25, 52, 305, 162),
#    (344, 243, 7, 0, 141),
#    (128, 240, 44, 16, 196),
#    (235, 70, 65, 197, 236),
#    (126, 236, 13, 77, 189),
#    (323, 136, 30, 155, 96),
#    (349, 57, 5, 156, 83),
#    (215, 182, 101, 94, 28),
#    (188, 103, 11, 250, 236),
#    (133, 131, 174, 6, 147),
#    (213, 164, 48, 193, 176),
#    (318, 14, 1, 31, 15),
#    (112, 224, 217, 25, 245),
#    (45, 144, 306, 130, 143),
#    (263, 44, 13, 230, 70),
#    (336, 71, 21, 98, 45),
#    (327, 90, 22, 190, 217),
#    (316, 31, 35, 67, 238),
#    (339, 34, 14, 217, 128),
#    (176, 241, 45, 101, 238),
#    (59, 184, 88, 91, 228),
#    (362, 39, 1, 21, 201),
#    (23, 100, 197, 130, 32),
#    (112, 62, 246, 26, 15),
#    (133, 92, 82, 9, 124),
#    (55, 24, 134, 38, 129),
#    (305, 109, 43, 29, 249),
#    (51, 219, 46, 32, 69),
#    (141, 231, 50, 45, 79),
#    (123, 130, 98, 183, 75),
#    (357, 227, 5, 101, 1),
#    (175, 158, 109, 124, 5),
#    (210, 133, 58, 182, 93),
#    (41, 141, 46, 39, 217),
#    (223, 163, 116, 179, 220),
#    (141, 88, 85, 275, 221),
#    (201, 73, 75, 152, 114),
#    (354, 239, 5, 7, 231),
#    (4, 194, 294, 146, 240),
#    (246, 244, 17, 26, 121)): 235389978323816,
#   ((84, 142, 209, 159, 49),
#    (111, 119, 137, 111, 49),
#    (240, 245, 62, 118, 248),
#    (295, 167, 53, 117, 238),
#    (144, 240, 113, 42, 135),
#    (9, 63, 355, 265, 152),
#    (96, 27, 248, 301, 119),
#    (311, 109, 0, 149, 51),
#    (238, 59, 33, 109, 225),
#    (324, 118, 2, 202, 79),
#    (179, 90, 18, 274, 187),
#    (135, 104, 4, 67, 237),
#    (278, 189, 44, 32, 196),
#    (349, 102, 12, 145, 34),
#    (43, 132, 44, 140, 79),
#    (118, 244, 138, 8, 224),
#    (24, 39, 299, 318, 47),
#    (72, 49, 22, 62, 87),
#    (227, 181, 58, 112, 117),
#    (166, 53, 132, 47, 46),
#    (206, 123, 118, 77, 172),
#    (110, 139, 108, 31, 6),
#    (338, 162, 26, 35, 122),
#    (286, 81, 61, 18, 103),
#    (69, 109, 69, 33, 26),
#    (86, 103, 277, 149, 162),
#    (4, 66, 332, 107, 99),
#    (103, 99, 243, 36, 241),
#    (188, 211, 149, 105, 237),
#    (345, 203, 13, 76, 145),
#    (6, 40, 253, 279, 87),
#    (87, 162, 35, 181, 136),
#    (160, 206, 62, 22, 179),
#    (44, 134, 237, 54, 10),
#    (290, 39, 42, 152, 252),
#    (171, 229, 180, 39, 43),
#    (193, 184, 113, 100, 135),
#    (55, 134, 60, 122, 74),
#    (93, 211, 45, 111, 175),
#    (12, 98, 259, 26, 205),
#    (63, 209, 166, 52, 22),
#    (134, 47, 156, 220, 125),
#    (70, 227, 268, 109, 154),
#    (48, 27, 146, 210, 179),
#    (259, 23, 20, 303, 231),
#    (129, 144, 0, 179, 220),
#    (176, 220, 67, 144, 96),
#    (20, 106, 186, 256, 195),
#    (187, 123, 113, 85, 130),
#    (16, 139, 73, 118, 197)): 312025075756717,
#   ((248, 12, 21, 238, 205),
#    (141, 96, 16, 191, 179),
#    (278, 141, 27, 41, 238),
#    (262, 182, 93, 9, 234),
#    (218, 6, 135, 72, 21),
#    (312, 64, 26, 196, 90),
#    (316, 238, 44, 122, 47),
#    (97, 142, 55, 24, 198),
#    (223, 41, 113, 269, 8),
#    (143, 25, 199, 310, 230),
#    (173, 177, 106, 177, 98),
#    (149, 64, 3, 248, 237),
#    (40, 91, 274, 194, 25),
#    (61, 224, 116, 58, 76),
#    (285, 86, 55, 57, 166),
#    (357, 181, 1, 33, 69),
#    (341, 187, 15, 154, 74),
#    (225, 230, 128, 29, 75),
#    (318, 12, 28, 57, 26),
#    (250, 2, 64, 326, 63),
#    (140, 89, 137, 132, 63),
#    (148, 173, 106, 163, 66),
#    (195, 119, 76, 15, 208),
#    (102, 196, 238, 20, 202),
#    (76, 115, 270, 118, 70),
#    (252, 238, 18, 58, 77),
#    (162, 42, 109, 242, 116),
#    (86, 214, 128, 135, 230),
#    (194, 48, 10, 19, 54),
#    (115, 126, 158, 189, 62),
#    (58, 140, 250, 22, 182),
#    (311, 81, 0, 169, 22),
#    (311, 139, 37, 113, 50),
#    (231, 63, 87, 121, 7),
#    (136, 94, 125, 200, 49),
#    (9, 64, 218, 96, 109),
#    (79, 160, 73, 114, 177),
#    (164, 7, 147, 85, 141),
#    (172, 206, 51, 22, 152),
#    (228, 99, 48, 16, 186),
#    (334, 171, 8, 136, 118),
#    (1, 197, 21, 119, 180),
#    (114, 101, 72, 231, 58),
#    (353, 148, 6, 22, 64),
#    (57, 134, 190, 86, 193),
#    (100, 16, 215, 173, 66),
#    (246, 45, 29, 7, 119),
#    (264, 51, 19, 68, 152),
#    (297, 220, 45, 89, 127),
#    (284, 154, 30, 93, 179)): 303555401335339})

# %% [markdown]
# A continuación definimos el cruce entre individuos

# %% [markdown]
# ### Ejercicio 6
# Define la función *cruza(i1,i2)* que tome dos individuos y devuelva una lista con los dos hijos obtenidos mediante la técnica de cruce en un punto.

# %%
# Solución:


def cruza(i1, i2):
    pos = random.randrange(1, len(i1)-1)
    hijo1 = i1[:pos] + i2[pos:]
    hijo2 = i1[pos:] + i2[:pos]
    return [hijo1, hijo2]


i1 = genera_individuo(20, im2array_shape)
i2 = genera_individuo(20, im2array_shape)

cruza(i1, i2)
# Out:
# [((85, 128, 11, 173, 110),
#   (230, 113, 29, 235, 209),
#   (191, 214, 39, 100, 50),
#   (103, 119, 42, 159, 63),
#   (49, 205, 86, 111, 107),
#   (262, 49, 22, 271, 90),
#   (207, 43, 0, 27, 42),
#   (49, 40, 75, 106, 113),
#   (75, 169, 249, 155, 219),
#   (43, 43, 176, 239, 62),
#   (326, 51, 37, 26, 197),
#   (215, 28, 79, 212, 36),
#   (309, 94, 10, 132, 94),
#   (110, 240, 98, 39, 9),
#   (201, 99, 158, 258, 107),
#   (257, 52, 32, 272, 172),
#   (19, 48, 175, 58, 26),
#   (103, 179, 215, 81, 8),
#   (25, 105, 204, 232, 191),
#   (181, 238, 150, 109, 129)),
#  ((205, 226, 84, 76, 19),
#   (53, 233, 187, 61, 167),
#   (277, 10, 30, 111, 32),
#   (209, 67, 136, 48, 27),
#   (261, 0, 59, 199, 168),
#   (113, 136, 205, 136, 132),
#   (95, 143, 254, 65, 161),
#   (56, 104, 283, 119, 33),
#   (267, 46, 71, 117, 214),
#   (166, 185, 17, 50, 88),
#   (258, 215, 46, 111, 179),
#   (186, 21, 126, 227, 94),
#   (78, 78, 75, 273, 111),
#   (24, 138, 219, 84, 162),
#   (30, 52, 67, 289, 4),
#   (220, 10, 60, 84, 112),
#   (126, 115, 211, 14, 187),
#   (281, 231, 8, 85, 23),
#   (260, 21, 77, 174, 158),
#   (128, 170, 34, 119, 58))]

# %% [markdown]
# ### Ejercicio 7
# Define la función *cruza_padres(padres)* que tome como entrada la lista *padres* con un número par de individuos y devuelva la lista de individuos obtenida aplicando la función *cruza(i1,i2)* donde *i1* es un individuo que ocupa una posición de índice par e *i2* es el siguiente individuo.

# %%
# Solución:

def cruza_padres(padres):
    hijos = []
    for j in range(0, len(padres), 2):
        hijos.extend(cruza(padres[j], padres[j+2]))
    return hijos

# %% [markdown]
# En esta práctica consideraremos que la mutación de un individuo consiste en sustituir uno de sus genes por otro elegido aleatoriamente.

# %% [markdown]
# ### Ejercicio 8
# Define la función *muta(ind)* que reciba como entrada un individuo *ind* y que, con una probabilidad *PROB_MUTACION* cambie uno de sus genes por otro gen aleatorio.

# %%
# Solución:

PROB_MUTACION = 0.4

test = genera_individuo(10, im2array_shape)

def muta(ind):
    ind_list = list(ind)
    for gen in range(0, len(ind_list)):
        if random.random() < PROB_MUTACION:
            #print(ind_list[gen])
            ind_list[gen] = genera_gen(im2array_shape)
            #print(f"Changed to {ind_list[gen]}")
    return tuple(ind_list)

test_mut = muta(test)

print("Old ind")
print(test)
print("\nNew ind")
print(test_mut)
# Out:
# Old ind
# ((99, 175, 140, 106, 106), (61, 232, 140, 55, 146), (162, 202, 25, 51, 64), (201, 150, 15, 199, 74), (67, 158, 226, 155, 133), (106, 91, 79, 253, 138), (252, 203, 107, 106, 200), (104, 204, 99, 70, 132), (326, 55, 36, 43, 51), (288, 84, 44, 145, 240))
#
# New ind
# ((99, 175, 140, 106, 106), (327, 161, 11, 30, 171), (162, 202, 25, 51, 64), (201, 150, 15, 199, 74), (67, 158, 226, 155, 133), (140, 241, 176, 28, 4), (252, 203, 107, 106, 200), (152, 21, 210, 254, 149), (326, 55, 36, 43, 51), (255, 178, 60, 140, 238))

# %% [markdown]
# ### Ejercicio 9
# Define una función *muta_individuos(poblacion)* que reciba como entrada a lista de individuos *poblacion* y aplique la función *muta* a cada uno de los individuos.

# %%
# Solución:

def muta_individuos(poblacion):
    output = []
    for ind in poblacion:
        output.append(muta(ind))
    return output

test = [genera_individuo(2, im2array_shape) for _ in range(5)]
print(test)
test = muta_individuos(test)
print(f"\n\n{test}")
# Out:
# [((113, 90, 88, 105, 218), (192, 57, 31, 133, 219)), ((216, 80, 10, 222, 111), (291, 174, 61, 125, 133)), ((24, 170, 212, 53, 14), (119, 214, 162, 72, 1)), ((10, 38, 149, 38, 230), (360, 188, 3, 155, 54)), ((36, 127, 158, 28, 131), (220, 82, 140, 195, 236))]
#
#
# [((240, 96, 65, 219, 184), (192, 57, 31, 133, 219)), ((201, 40, 68, 258, 206), (291, 174, 61, 125, 133)), ((166, 113, 23, 33, 213), (119, 214, 162, 72, 1)), ((59, 242, 65, 68, 243), (130, 206, 128, 79, 33)), ((210, 65, 121, 215, 35), (220, 82, 140, 195, 236))]

# %% [markdown]
# A continuación definimos el algoritmo que permite encontrar una nueva generación a partir de una dada.

# %% [markdown]
# ### Ejercicio 10
# Define una función *nueva_generacion(poblacion,n_padres,n_directos,dic)* que reciba como entrada:
# * *poblacion* es una población de individuos
# * *n_padres* es un número que determina cuántos individuos seleccionamos por torneo para ser padres
# * *n_directos* es un número que determina cuántos individuos seleccionamos por torneo para pasar directamente a la siguiente generación.
# * dic es un diccionario de pares individuo:fitness
#
# La función debe seleccionar un conjunto de individuos para ser padres y otro para pasar directamente a la siguiente generación y a partir de los padres se debe genera un conjunto de hijos por cruce. La función debe devolver una tupla *(nuevo_dic,nueva_pob)* donde *nueva_pob* es una lista de individuos formada por los individuos que han pasado directamente a la siguiente generación más el resultado de aplicar la función de mutación a los hijos.

# %%
# Solución:

def seleccion_por_torneo(poblacion, num_seleccionados, dic):
    nuevo_dic = dic.copy()
    seleccion = []
    
    for _ in range(num_seleccionados):
        sel_torneo = selecciona_uno_por_torneo(poblacion, nuevo_dic)

        nuevo_dic = sel_torneo[1]
            
        seleccion.append(sel_torneo[0])

    return seleccion, nuevo_dic

# %%
# Solución:

def nueva_generacion(poblacion, n_padres, n_directos, dic):
    padres, pad_dic = seleccion_por_torneo(poblacion, n_padres, dic)

    directos, dir_dic = seleccion_por_torneo(poblacion, n_directos, dic)

    nuevo_dic = dic.copy()

    nuevo_dic.update(pad_dic)
    nuevo_dic.update(dir_dic)

    hijos = []

    for j in range(0, len(padres), 2):
        if j + 1 < len(padres):
            padre1 = padres[j]
            padre2 = padres[j+1]
            hijo1, hijo2 = cruza(padre1, padre2)
            hijos.append(hijo1)
            hijos.append(hijo2)

    hijos = list(muta(hijos))
    return nuevo_dic, tuple(directos + hijos)


pob = poblacion_inicial()

nueva_generacion(pob, 4, 4, {})
# Out:
# ({((74, 168, 80, 142, 8),
#    (351, 180, 7, 145, 100),
#    (121, 72, 184, 212, 208),
#    (144, 94, 0, 139, 164),
#    (303, 150, 28, 177, 106),
#    (119, 170, 12, 12, 230),
#    (68, 145, 24, 206, 126),
#    (270, 84, 42, 5, 81),
#    (17, 135, 192, 98, 163),
#    (223, 90, 15, 21, 64),
#    (302, 123, 13, 164, 163),
#    (307, 34, 15, 44, 39),
#    (254, 179, 84, 33, 25),
#    (292, 100, 10, 149, 121),
#    (323, 158, 3, 142, 177),
#    (92, 229, 132, 38, 182),
#    (314, 111, 38, 82, 106),
#    (64, 240, 91, 82, 81),
#    (312, 159, 44, 86, 117),
#    (351, 208, 3, 65, 213)): 65227677423932,
#   ((305, 194, 8, 91, 231),
#    (0, 64, 59, 279, 143),
#    (306, 124, 21, 169, 82),
#    (79, 93, 111, 139, 200),
#    (285, 36, 46, 269, 133),
#    (274, 73, 76, 214, 40),
#    (67, 52, 51, 184, 167),
#    (207, 62, 104, 151, 188),
#    (159, 225, 182, 11, 31),
#    (2, 59, 273, 183, 54),
#    (295, 41, 11, 235, 67),
#    (142, 18, 178, 138, 103),
#    (355, 147, 9, 133, 70),
#    (255, 124, 2, 91, 173),
#    (283, 241, 24, 5, 138),
#    (225, 121, 133, 60, 211),
#    (256, 104, 76, 184, 159),
#    (356, 181, 6, 33, 212),
#    (254, 220, 19, 140, 186),
#    (222, 17, 134, 49, 201)): 279507879722371,
#   ((226, 32, 74, 143, 173),
#    (176, 54, 71, 308, 157),
#    (281, 71, 63, 212, 20),
#    (232, 229, 73, 84, 130),
#    (165, 109, 53, 50, 227),
#    (17, 77, 261, 252, 95),
#    (334, 207, 28, 41, 169),
#    (198, 42, 4, 105, 20),
#    (105, 48, 14, 79, 164),
#    (160, 61, 173, 228, 129),
#    (10, 191, 281, 22, 48),
#    (260, 185, 83, 150, 203),
#    (96, 161, 98, 24, 64),
#    (351, 4, 5, 26, 76),
#    (332, 122, 18, 182, 201),
#    (197, 160, 39, 20, 82),
#    (160, 117, 28, 29, 214),
#    (127, 245, 105, 78, 201),
#    (161, 57, 73, 181, 112),
#    (110, 104, 94, 3, 74)): 211832084329750,
#   ((87, 230, 5, 90, 29),
#    (361, 65, 0, 220, 115),
#    (88, 89, 162, 26, 179),
#    (120, 178, 62, 62, 121),
#    (6, 81, 181, 229, 43),
#    (208, 104, 61, 38, 165),
#    (136, 77, 13, 193, 20),
#    (298, 185, 11, 119, 160),
#    (61, 147, 264, 135, 137),
#    (322, 75, 3, 245, 204),
#    (293, 185, 66, 17, 52),
#    (156, 88, 44, 258, 242),
#    (12, 72, 297, 174, 16),
#    (290, 108, 63, 228, 96),
#    (223, 91, 122, 140, 128),
#    (86, 96, 179, 41, 246),
#    (26, 236, 201, 99, 100),
#    (211, 78, 16, 61, 203),
#    (360, 186, 0, 139, 64),
#    (173, 6, 23, 93, 202)): 245534691169523,
#   ((313, 63, 13, 298, 9),
#    (185, 110, 141, 226, 25),
#    (204, 134, 72, 55, 13),
#    (131, 230, 179, 97, 171),
#    (59, 68, 153, 268, 151),
#    (74, 36, 89, 257, 200),
#    (99, 60, 152, 34, 210),
#    (144, 127, 102, 28, 21),
#    (97, 93, 157, 248, 180),
#    (34, 226, 137, 89, 58),
#    (82, 213, 1, 50, 107),
#    (103, 213, 16, 86, 74),
#    (358, 19, 6, 325, 55),
#    (58, 95, 19, 88, 67),
#    (66, 107, 100, 134, 93),
#    (280, 161, 36, 189, 119),
#    (128, 218, 194, 12, 171),
#    (163, 226, 195, 52, 223),
#    (22, 4, 221, 182, 230),
#    (38, 21, 126, 115, 211)): 183115934217841,
#   ((267, 25, 15, 211, 95),
#    (73, 244, 19, 82, 43),
#    (236, 5, 60, 46, 33),
#    (245, 166, 54, 94, 27),
#    (362, 227, 2, 57, 11),
#    (280, 89, 51, 172, 47),
#    (259, 48, 55, 164, 111),
#    (337, 186, 24, 89, 27),
#    (347, 26, 2, 61, 42),
#    (146, 147, 41, 138, 230),
#    (237, 162, 83, 51, 136),
#    (320, 198, 40, 12, 55),
#    (304, 227, 7, 83, 91),
#    (164, 52, 35, 169, 182),
#    (99, 115, 60, 122, 135),
#    (249, 23, 21, 263, 160),
#    (219, 88, 127, 189, 199),
#    (228, 104, 88, 233, 11),
#    (100, 237, 45, 80, 191),
#    (204, 207, 158, 10, 9)): 94845771263146,
#   ((325, 116, 2, 243, 67),
#    (329, 111, 8, 23, 123),
#    (54, 138, 47, 142, 2),
#    (130, 100, 50, 188, 135),
#    (197, 163, 27, 64, 145),
#    (222, 136, 75, 128, 154),
#    (126, 220, 223, 26, 224),
#    (62, 244, 49, 32, 160),
#    (181, 235, 133, 96, 176),
#    (347, 41, 16, 35, 80),
#    (42, 162, 146, 182, 121),
#    (306, 196, 20, 133, 19),
#    (114, 188, 25, 160, 64),
#    (104, 94, 255, 181, 184),
#    (87, 177, 62, 187, 216),
#    (137, 124, 87, 231, 131),
#    (80, 214, 153, 35, 76),
#    (323, 83, 36, 45, 129),
#    (56, 184, 193, 71, 243),
#    (313, 230, 18, 76, 163)): 93776323428460,
#   ((301, 142, 12, 126, 118),
#    (126, 28, 47, 223, 232),
#    (257, 199, 24, 39, 227),
#    (45, 186, 45, 153, 42),
#    (315, 100, 42, 189, 252),
#    (43, 126, 276, 145, 124),
#    (305, 241, 18, 106, 110),
#    (285, 153, 18, 117, 88),
#    (281, 94, 29, 125, 72),
#    (334, 119, 18, 205, 108),
#    (324, 134, 30, 79, 97),
#    (53, 224, 176, 23, 15),
#    (305, 54, 43, 66, 208),
#    (12, 208, 23, 136, 249),
#    (125, 151, 31, 24, 88),
#    (362, 38, 2, 21, 46),
#    (204, 83, 64, 57, 79),
#    (104, 212, 17, 93, 86),
#    (151, 139, 74, 163, 71),
#    (256, 63, 16, 118, 183)): 95915217101869,
#   ((45, 228, 269, 109, 35),
#    (304, 43, 41, 171, 39),
#    (175, 125, 64, 200, 154),
#    (274, 97, 87, 177, 29),
#    (292, 202, 17, 105, 55),
#    (267, 27, 27, 128, 8),
#    (364, 109, 0, 100, 189),
#    (359, 112, 5, 16, 160),
#    (290, 215, 49, 125, 171),
#    (274, 7, 85, 125, 52),
#    (245, 193, 53, 150, 137),
#    (133, 39, 211, 291, 57),
#    (165, 241, 123, 73, 86),
#    (25, 87, 4, 7, 151),
#    (283, 122, 22, 43, 129),
#    (173, 56, 101, 100, 72),
#    (213, 60, 137, 84, 30),
#    (184, 74, 41, 79, 165),
#    (173, 133, 181, 117, 57),
#    (269, 18, 52, 128, 50)): 197997995655167,
#   ((258, 146, 8, 115, 170),
#    (22, 181, 201, 127, 130),
#    (321, 52, 40, 232, 67),
#    (203, 144, 4, 17, 161),
#    (303, 231, 36, 126, 114),
#    (311, 8, 1, 308, 16),
#    (321, 204, 27, 113, 140),
#    (81, 135, 95, 205, 40),
#    (50, 51, 301, 274, 63),
#    (239, 197, 47, 117, 131),
#    (3, 116, 310, 84, 140),
#    (118, 163, 143, 97, 213),
#    (184, 112, 114, 131, 190),
#    (296, 225, 61, 17, 117),
#    (43, 112, 163, 162, 90),
#    (122, 125, 19, 40, 150),
#    (49, 205, 293, 107, 116),
#    (109, 128, 171, 87, 242),
#    (224, 213, 71, 60, 96),
#    (64, 54, 206, 272, 86)): 251758097919893,
#   ((44, 228, 71, 2, 113),
#    (153, 178, 195, 93, 114),
#    (281, 40, 21, 55, 17),
#    (241, 110, 31, 243, 164),
#    (145, 221, 72, 100, 215),
#    (73, 22, 205, 145, 105),
#    (79, 15, 238, 291, 41),
#    (208, 45, 142, 193, 246),
#    (137, 101, 137, 124, 222),
#    (296, 76, 61, 187, 167),
#    (103, 123, 161, 86, 201),
#    (24, 140, 17, 4, 139),
#    (7, 43, 327, 296, 2),
#    (110, 105, 183, 197, 37),
#    (112, 30, 213, 144, 44),
#    (331, 110, 30, 175, 125),
#    (59, 238, 17, 5, 215),
#    (331, 218, 9, 86, 223),
#    (67, 3, 187, 275, 88),
#    (249, 31, 24, 17, 67)): 327048870513908,
#   ((254, 240, 87, 74, 100),
#    (98, 93, 250, 39, 169),
#    (59, 239, 43, 2, 156),
#    (56, 117, 162, 103, 64),
#    (59, 95, 59, 17, 239),
#    (112, 39, 105, 266, 99),
#    (340, 236, 16, 48, 148),
#    (97, 18, 222, 10, 3),
#    (156, 125, 180, 221, 52),
#    (35, 69, 258, 30, 201),
#    (158, 7, 129, 142, 113),
#    (192, 186, 19, 27, 49),
#    (356, 181, 8, 29, 33),
#    (340, 137, 3, 118, 209),
#    (153, 36, 72, 174, 193),
#    (221, 16, 7, 218, 213),
#    (315, 199, 42, 128, 27),
#    (121, 118, 27, 102, 70),
#    (179, 136, 182, 106, 56),
#    (298, 170, 22, 65, 11)): 194360157557643,
#   ((236, 213, 19, 48, 89),
#    (38, 230, 105, 76, 133),
#    (323, 186, 33, 65, 15),
#    (71, 85, 14, 275, 156),
#    (111, 227, 223, 96, 171),
#    (76, 83, 113, 228, 193),
#    (271, 38, 84, 227, 11),
#    (39, 22, 62, 279, 248),
#    (123, 92, 83, 142, 222),
#    (224, 177, 60, 53, 59),
#    (122, 66, 151, 56, 68),
#    (73, 82, 267, 268, 238),
#    (137, 176, 193, 31, 198),
#    (71, 25, 100, 15, 18),
#    (77, 169, 71, 19, 185),
#    (296, 109, 31, 196, 157),
#    (350, 227, 6, 17, 215),
#    (51, 32, 34, 19, 118),
#    (17, 190, 285, 72, 171),
#    (98, 151, 86, 48, 34)): 166588900851732,
#   ((239, 83, 77, 226, 165),
#    (217, 54, 18, 308, 251),
#    (324, 104, 32, 243, 38),
#    (212, 98, 133, 43, 54),
#    (170, 173, 153, 184, 114),
#    (44, 80, 314, 6, 247),
#    (95, 87, 112, 67, 155),
#    (299, 224, 58, 41, 215),
#    (52, 2, 121, 225, 113),
#    (52, 192, 52, 79, 214),
#    (35, 241, 77, 68, 11),
#    (105, 149, 121, 48, 65),
#    (1, 213, 106, 26, 238),
#    (88, 227, 177, 39, 122),
#    (360, 113, 0, 193, 110),
#    (77, 211, 212, 141, 57),
#    (253, 165, 30, 23, 60),
#    (31, 165, 292, 69, 107),
#    (79, 178, 234, 142, 151),
#    (224, 162, 56, 130, 193)): 179761564830807,
#   ((116, 166, 110, 29, 248),
#    (17, 93, 293, 138, 59),
#    (19, 170, 302, 168, 13),
#    (213, 5, 130, 258, 94),
#    (63, 117, 164, 13, 202),
#    (103, 189, 166, 134, 5),
#    (220, 102, 35, 259, 200),
#    (349, 12, 12, 89, 220),
#    (291, 136, 33, 179, 86),
#    (312, 21, 44, 110, 168),
#    (216, 1, 2, 321, 80),
#    (95, 244, 60, 11, 151),
#    (331, 150, 28, 174, 58),
#    (44, 217, 64, 75, 94),
#    (213, 48, 79, 135, 84),
#    (155, 6, 34, 297, 180),
#    (288, 216, 73, 0, 219),
#    (278, 92, 39, 182, 175),
#    (75, 108, 246, 56, 182),
#    (170, 160, 114, 125, 41)): 229445743333488,
#   ((215, 144, 24, 102, 76),
#    (362, 85, 1, 212, 199),
#    (332, 88, 5, 274, 132),
#    (83, 138, 251, 5, 146),
#    (6, 74, 312, 220, 107),
#    (106, 80, 78, 174, 156),
#    (307, 164, 32, 115, 49),
#    (336, 244, 18, 119, 44),
#    (121, 35, 236, 144, 192),
#    (309, 4, 43, 141, 143),
#    (364, 175, 0, 91, 232),
#    (231, 44, 7, 79, 187),
#    (158, 58, 187, 258, 222),
#    (334, 178, 7, 23, 199),
#    (78, 202, 38, 74, 18),
#    (46, 167, 134, 166, 91),
#    (133, 235, 70, 104, 94),
#    (234, 135, 25, 143, 19),
#    (47, 180, 219, 13, 171),
#    (40, 171, 39, 16, 48)): 208039627621654,
#   ((322, 54, 21, 189, 151),
#    (298, 168, 65, 60, 15),
#    (32, 42, 331, 42, 185),
#    (173, 167, 164, 12, 92),
#    (104, 92, 46, 259, 230),
#    (109, 82, 98, 173, 251),
#    (52, 145, 18, 66, 85),
#    (184, 36, 107, 279, 77),
#    (129, 196, 136, 72, 125),
#    (277, 141, 83, 177, 14),
#    (172, 36, 66, 74, 44),
#    (298, 185, 9, 179, 56),
#    (294, 204, 15, 130, 35),
#    (44, 113, 91, 98, 200),
#    (29, 17, 245, 186, 153),
#    (347, 159, 12, 118, 48),
#    (152, 18, 197, 212, 247),
#    (204, 129, 137, 66, 75),
#    (344, 217, 1, 3, 80),
#    (70, 191, 161, 113, 161)): 190052305003617,
#   ((261, 32, 97, 330, 35),
#    (339, 70, 25, 269, 107),
#    (121, 39, 65, 290, 87),
#    (128, 184, 124, 78, 156),
#    (168, 48, 188, 149, 241),
#    (324, 184, 37, 123, 229),
#    (127, 104, 102, 79, 206),
#    (319, 206, 29, 106, 208),
#    (133, 25, 230, 17, 211),
#    (232, 29, 113, 175, 199),
#    (319, 122, 23, 194, 238),
#    (113, 40, 11, 98, 117),
#    (207, 17, 31, 323, 115),
#    (310, 137, 42, 119, 193),
#    (216, 199, 2, 89, 122),
#    (122, 81, 21, 250, 35),
#    (263, 30, 45, 201, 101),
#    (288, 169, 13, 68, 223),
#    (188, 163, 73, 92, 55),
#    (358, 165, 5, 143, 111)): 169586788022909,
#   ((21, 99, 209, 97, 171),
#    (149, 194, 134, 13, 215),
#    (217, 7, 72, 8, 177),
#    (47, 135, 183, 203, 163),
#    (279, 239, 32, 1, 241),
#    (129, 152, 117, 141, 151),
#    (188, 89, 117, 142, 125),
#    (183, 50, 165, 226, 200),
#    (325, 179, 2, 131, 209),
#    (13, 114, 92, 191, 201),
#    (207, 97, 131, 226, 147),
#    (178, 126, 129, 26, 5),
#    (91, 188, 91, 151, 95),
#    (111, 107, 46, 170, 237),
#    (261, 111, 95, 62, 113),
#    (36, 1, 31, 75, 179),
#    (212, 69, 65, 98, 127),
#    (88, 33, 218, 294, 1),
#    (66, 15, 137, 201, 111),
#    (20, 191, 159, 41, 27)): 247553324775644,
#   ((181, 154, 61, 67, 140),
#    (255, 85, 103, 253, 216),
#    (147, 158, 179, 84, 234),
#    (178, 206, 182, 99, 246),
#    (67, 66, 9, 37, 104),
#    (167, 183, 172, 13, 196),
#    (171, 36, 170, 173, 97),
#    (227, 1, 6, 51, 176),
#    (1, 159, 316, 9, 105),
#    (158, 21, 63, 118, 30),
#    (21, 153, 47, 83, 136),
#    (147, 91, 160, 114, 147),
#    (126, 128, 51, 102, 144),
#    (255, 187, 81, 169, 195),
#    (355, 175, 0, 178, 68),
#    (177, 132, 21, 199, 99),
#    (56, 203, 168, 13, 136),
#    (347, 100, 16, 40, 133),
#    (239, 153, 76, 105, 230),
#    (229, 141, 84, 80, 146)): 133302905642950,
#   ((231, 41, 27, 287, 174),
#    (77, 91, 66, 41, 95),
#    (309, 121, 15, 144, 118),
#    (294, 112, 6, 65, 153),
#    (360, 3, 1, 293, 180),
#    (228, 78, 79, 270, 127),
#    (342, 234, 2, 58, 255),
#    (268, 81, 22, 178, 223),
#    (301, 139, 8, 26, 192),
#    (334, 204, 12, 117, 55),
#    (178, 84, 179, 165, 187),
#    (120, 242, 44, 53, 200),
#    (226, 159, 115, 28, 85),
#    (311, 237, 12, 29, 108),
#    (336, 162, 0, 65, 48),
#    (291, 238, 24, 57, 168),
#    (224, 72, 35, 27, 245),
#    (288, 16, 76, 168, 161),
#    (252, 216, 89, 7, 180),
#    (98, 37, 45, 100, 238)): 65601339892206,
#   ((335, 67, 25, 288, 130),
#    (228, 1, 94, 356, 87),
#    (198, 142, 96, 196, 255),
#    (225, 77, 38, 14, 122),
#    (151, 107, 201, 86, 57),
#    (333, 143, 8, 29, 138),
#    (221, 245, 7, 91, 157),
#    (189, 16, 149, 47, 220),
#    (76, 10, 147, 52, 28),
#    (208, 2, 38, 263, 30),
#    (34, 179, 318, 179, 125),
#    (357, 108, 4, 113, 200),
#    (198, 150, 71, 146, 157),
#    (13, 163, 257, 171, 228),
#    (238, 207, 124, 115, 198),
#    (232, 181, 47, 71, 235),
#    (141, 101, 23, 214, 11),
#    (325, 170, 0, 110, 208),
#    (154, 77, 26, 149, 131),
#    (85, 110, 73, 247, 226)): 205093280908550,
#   ((355, 170, 5, 191, 195),
#    (30, 45, 121, 149, 175),
#    (266, 82, 85, 239, 151),
#    (302, 122, 12, 135, 224),
#    (118, 28, 90, 38, 163),
#    (75, 173, 129, 37, 75),
#    (20, 190, 291, 23, 137),
#    (71, 76, 105, 114, 4),
#    (244, 8, 51, 282, 83),
#    (272, 150, 30, 182, 232),
#    (162, 103, 185, 146, 69),
#    (275, 245, 47, 69, 135),
#    (21, 38, 46, 166, 222),
#    (248, 129, 79, 78, 117),
#    (79, 30, 18, 277, 235),
#    (191, 208, 81, 109, 27),
#    (189, 188, 71, 93, 148),
#    (278, 240, 63, 42, 131),
#    (120, 54, 232, 20, 205),
#    (67, 112, 186, 7, 38)): 169372038694996,
#   ((3, 101, 180, 238, 128),
#    (264, 228, 11, 20, 175),
#    (353, 124, 6, 209, 69),
#    (302, 67, 22, 218, 96),
#    (76, 179, 11, 53, 72),
#    (293, 96, 36, 233, 67),
#    (162, 21, 64, 84, 205),
#    (205, 144, 138, 61, 12),
#    (333, 35, 27, 9, 245),
#    (17, 87, 237, 24, 145),
#    (323, 212, 1, 60, 167),
#    (213, 221, 106, 52, 131),
#    (349, 107, 11, 153, 42),
#    (12, 91, 160, 194, 228),
#    (87, 117, 99, 159, 163),
#    (99, 59, 183, 22, 19),
#    (43, 192, 184, 167, 106),
#    (14, 149, 235, 33, 79),
#    (8, 171, 354, 108, 87),
#    (303, 181, 4, 49, 97)): 195395245210963,
#   ((243, 56, 14, 111, 9),
#    (352, 31, 8, 168, 67),
#    (325, 164, 17, 127, 76),
#    (152, 190, 83, 50, 38),
#    (140, 15, 97, 234, 5),
#    (103, 189, 5, 170, 97),
#    (31, 142, 261, 176, 176),
#    (50, 161, 214, 90, 140),
#    (282, 66, 80, 204, 38),
#    (308, 46, 7, 87, 86),
#    (77, 138, 110, 204, 170),
#    (125, 225, 201, 127, 242),
#    (351, 50, 8, 191, 197),
#    (116, 29, 124, 156, 109),
#    (157, 119, 16, 138, 141),
#    (169, 140, 191, 159, 13),
#    (136, 3, 19, 126, 39),
#    (200, 112, 9, 174, 94),
#    (28, 124, 246, 82, 221),
#    (92, 204, 223, 138, 203)): 220718371260464,
#   ((359, 194, 3, 104, 178),
#    (219, 214, 21, 46, 146),
#    (68, 74, 67, 29, 49),
#    (100, 128, 172, 203, 180),
#    (287, 41, 7, 84, 106),
#    (151, 62, 112, 4, 54),
#    (339, 78, 25, 6, 113),
#    (27, 224, 170, 121, 175),
#    (360, 173, 3, 12, 14),
#    (323, 31, 19, 74, 248),
#    (282, 63, 34, 222, 255),
#    (265, 59, 62, 185, 85),
#    (57, 170, 80, 96, 43),
#    (259, 57, 75, 11, 103),
#    (3, 15, 325, 90, 1),
#    (248, 153, 79, 134, 60),
#    (135, 89, 124, 189, 6),
#    (348, 23, 2, 214, 65),
#    (21, 28, 286, 318, 213),
#    (24, 206, 140, 137, 44)): 264020228730374,
#   ((349, 64, 2, 143, 99),
#    (246, 1, 93, 292, 60),
#    (315, 98, 30, 29, 59),
#    (359, 244, 5, 65, 204),
#    (132, 170, 35, 24, 92),
#    (117, 244, 167, 60, 118),
#    (212, 157, 100, 150, 13),
#    (170, 67, 27, 59, 15),
#    (269, 193, 15, 81, 124),
#    (351, 9, 4, 64, 79),
#    (185, 28, 160, 165, 61),
#    (172, 75, 145, 180, 160),
#    (362, 42, 2, 192, 95),
#    (50, 40, 23, 255, 77),
#    (329, 227, 10, 125, 68),
#    (70, 73, 65, 198, 25),
#    (145, 43, 214, 11, 103),
#    (17, 185, 335, 178, 86),
#    (11, 40, 98, 219, 205),
#    (71, 42, 44, 127, 233)): 230128643302596},
#  (((215, 144, 24, 102, 76),
#    (362, 85, 1, 212, 199),
#    (332, 88, 5, 274, 132),
#    (83, 138, 251, 5, 146),
#    (6, 74, 312, 220, 107),
#    (106, 80, 78, 174, 156),
#    (307, 164, 32, 115, 49),
#    (336, 244, 18, 119, 44),
#    (121, 35, 236, 144, 192),
#    (309, 4, 43, 141, 143),
#    (364, 175, 0, 91, 232),
#    (231, 44, 7, 79, 187),
#    (158, 58, 187, 258, 222),
#    (334, 178, 7, 23, 199),
#    (78, 202, 38, 74, 18),
#    (46, 167, 134, 166, 91),
#    (133, 235, 70, 104, 94),
#    (234, 135, 25, 143, 19),
#    (47, 180, 219, 13, 171),
#    (40, 171, 39, 16, 48)),
#   ((21, 99, 209, 97, 171),
#    (149, 194, 134, 13, 215),
#    (217, 7, 72, 8, 177),
#    (47, 135, 183, 203, 163),
#    (279, 239, 32, 1, 241),
#    (129, 152, 117, 141, 151),
#    (188, 89, 117, 142, 125),
#    (183, 50, 165, 226, 200),
#    (325, 179, 2, 131, 209),
#    (13, 114, 92, 191, 201),
#    (207, 97, 131, 226, 147),
#    (178, 126, 129, 26, 5),
#    (91, 188, 91, 151, 95),
#    (111, 107, 46, 170, 237),
#    (261, 111, 95, 62, 113),
#    (36, 1, 31, 75, 179),
#    (212, 69, 65, 98, 127),
#    (88, 33, 218, 294, 1),
#    (66, 15, 137, 201, 111),
#    (20, 191, 159, 41, 27)),
#   ((335, 67, 25, 288, 130),
#    (228, 1, 94, 356, 87),
#    (198, 142, 96, 196, 255),
#    (225, 77, 38, 14, 122),
#    (151, 107, 201, 86, 57),
#    (333, 143, 8, 29, 138),
#    (221, 245, 7, 91, 157),
#    (189, 16, 149, 47, 220),
#    (76, 10, 147, 52, 28),
#    (208, 2, 38, 263, 30),
#    (34, 179, 318, 179, 125),
#    (357, 108, 4, 113, 200),
#    (198, 150, 71, 146, 157),
#    (13, 163, 257, 171, 228),
#    (238, 207, 124, 115, 198),
#    (232, 181, 47, 71, 235),
#    (141, 101, 23, 214, 11),
#    (325, 170, 0, 110, 208),
#    (154, 77, 26, 149, 131),
#    (85, 110, 73, 247, 226)),
#   ((359, 194, 3, 104, 178),
#    (219, 214, 21, 46, 146),
#    (68, 74, 67, 29, 49),
#    (100, 128, 172, 203, 180),
#    (287, 41, 7, 84, 106),
#    (151, 62, 112, 4, 54),
#    (339, 78, 25, 6, 113),
#    (27, 224, 170, 121, 175),
#    (360, 173, 3, 12, 14),
#    (323, 31, 19, 74, 248),
#    (282, 63, 34, 222, 255),
#    (265, 59, 62, 185, 85),
#    (57, 170, 80, 96, 43),
#    (259, 57, 75, 11, 103),
#    (3, 15, 325, 90, 1),
#    (248, 153, 79, 134, 60),
#    (135, 89, 124, 189, 6),
#    (348, 23, 2, 214, 65),
#    (21, 28, 286, 318, 213),
#    (24, 206, 140, 137, 44)),
#   (326, 85, 12, 165, 205),
#   ((256, 104, 76, 184, 159),
#    (356, 181, 6, 33, 212),
#    (254, 220, 19, 140, 186),
#    (222, 17, 134, 49, 201),
#    (313, 63, 13, 298, 9),
#    (185, 110, 141, 226, 25),
#    (204, 134, 72, 55, 13),
#    (131, 230, 179, 97, 171),
#    (59, 68, 153, 268, 151),
#    (74, 36, 89, 257, 200),
#    (99, 60, 152, 34, 210),
#    (144, 127, 102, 28, 21),
#    (97, 93, 157, 248, 180),
#    (34, 226, 137, 89, 58),
#    (82, 213, 1, 50, 107),
#    (103, 213, 16, 86, 74),
#    (358, 19, 6, 325, 55),
#    (58, 95, 19, 88, 67),
#    (66, 107, 100, 134, 93),
#    (280, 161, 36, 189, 119)),
#   ((44, 228, 71, 2, 113),
#    (153, 178, 195, 93, 114),
#    (281, 40, 21, 55, 17),
#    (241, 110, 31, 243, 164),
#    (145, 221, 72, 100, 215),
#    (73, 22, 205, 145, 105),
#    (79, 15, 238, 291, 41),
#    (208, 45, 142, 193, 246),
#    (137, 101, 137, 124, 222),
#    (296, 76, 61, 187, 167),
#    (103, 123, 161, 86, 201),
#    (24, 140, 17, 4, 139),
#    (7, 43, 327, 296, 2),
#    (110, 105, 183, 197, 37),
#    (112, 30, 213, 144, 44),
#    (331, 110, 30, 175, 125),
#    (59, 238, 17, 5, 215),
#    (331, 218, 9, 86, 223),
#    (75, 108, 246, 56, 182),
#    (170, 160, 114, 125, 41)),
#   (245, 146, 55, 49, 154)))

# %% [markdown]
# Por último definimos el algoritmo genetico en el que se genera un a población inicial y se van creando nuevas generaciones usando las funciones anteriores. Además, cada *PASO_IMP* imprimimos la imagen correspondiente al mejor individuo. La función devuelve la lista de los valores *fitnes*  de estos individuos para poder luego representar gráficamente la evolución de la función a lo largo de las iteraciones.

# %%
# ga_{:>08}.jpg rellena hasta 8 posiciones con 0 por la izquierda

# %%
# Solución:
def algoritmo_genetico():
    poblacion= poblacion_inicial()
    dic = {}
    n_padres = round(TAMANO_POB * PROP_CRUCES)
    n_padres = (n_padres if n_padres%2==0 else n_padres-1)
    n_directos = TAMANO_POB - n_padres
    mejores = []
    for counter in range(ITERACIONES):
        if counter%PASO_IMP == 0:
            print(counter)
            nuevo_dic = {}
            actual = 'inicial'
            min = float('inf')
            for ind in poblacion:
                f_ind = fitness_1(ind)
                nuevo_dic[ind] = f_ind
                if f_ind < min:
                    actual = ind
                    min = f_ind
            img_mejor = decodifica(actual).astype('uint8')
            imageio.imwrite('ga_{:>08}.jpg'.format(counter//PASO_IMP),img_mejor)
            mejores.append(min)
            dic, poblacion = nueva_generacion(poblacion,n_padres,n_directos,dic)
        else:
            dic, poblacion = nueva_generacion(poblacion,n_padres,n_directos,dic)
            print('.',end='')
    return mejores

# %%
# sal_ag_1 = algoritmo_genetico(fitness_1)
sal_ag_1 = algoritmo_genetico()
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 2
#       1 # sal_ag_1 = algoritmo_genetico(fitness_1)
# ----> 2 sal_ag_1 = algoritmo_genetico()
#
# Cell In[124], line 26, in algoritmo_genetico()
#      24         dic, poblacion = nueva_generacion(poblacion,n_padres,n_directos,dic)
#      25     else:
# ---> 26         dic, poblacion = nueva_generacion(poblacion,n_padres,n_directos,dic)
#      27         print('.',end='')
#      28 return mejores
#
# Cell In[122], line 4, in nueva_generacion(poblacion, n_padres, n_directos, dic)
#       3 def nueva_generacion(poblacion, n_padres, n_directos, dic):
# ----> 4     padres, pad_dic = seleccion_por_torneo(poblacion, n_padres, dic)
#       6     directos, dir_dic = seleccion_por_torneo(poblacion, n_directos, dic)
#       8     nuevo_dic = dic.copy()
#
# Cell In[22], line 8, in seleccion_por_torneo(poblacion, num_seleccionados, dic)
#       5 seleccion = []
#       7 for _ in range(num_seleccionados):
# ----> 8     sel_torneo = selecciona_uno_por_torneo(poblacion, nuevo_dic)
#      10     nuevo_dic = sel_torneo[1]
#      12     seleccion.append(sel_torneo[0])
#
# Cell In[20], line 12, in selecciona_uno_por_torneo(poblacion, dic)
#      10 for ind in participantes:
#      11     if not ind in nuevo_dic:
# ---> 12         nuevo_dic[ind] = fitness_1(ind)
#      13     if nuevo_dic[ind] > nuevo_dic[max_cand]:
#      14         max_cand = ind
#
# Cell In[18], line 2, in fitness_1(ind)
#       1 def fitness_1(ind):
# ----> 2     return np.sum(np.absolute(decodifica(ind) - IM2ARRAY))
#
# Cell In[13], line 5, in decodifica(ind)
#       3 array_sal = np.zeros(im2array_shape,dtype='uint32')
#       4 array_255 = np.full(im2array_shape,255,dtype='uint32')
# ----> 5 for (x,y,dx,dy,c) in ind:
#       6     array_sal[x:x+dx,y:y+dy]+= 255 - c
#       7 mini = np.minimum(array_sal,array_255)
#
# TypeError: cannot unpack non-iterable int object

# %%
# plt.plot(sal_ag_1[1:])
# plt.show()

# %% [markdown]
# ### Ejercicio 11
# La función fitness definida anteriormente es fácil de implementar, pero no es la más apropiada para comparar imágenes. Vamos a considerar otra medida basada en la similaridad estructural para comparar imágenes

# %%
def fitness_2(ind):
    dec = decodifica(ind)
    return 1 - ssim(IM2ARRAY, dec, data_range=dec.max() - dec.min())

# %%
# Ejemplo:
fitness_2(ind_1)
# Out:
# 0.7767097807873224

# %%
sal_ag_2 = algoritmo_genetico()
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 sal_ag_2 = algoritmo_genetico()
#
# Cell In[124], line 26, in algoritmo_genetico()
#      24         dic, poblacion = nueva_generacion(poblacion,n_padres,n_directos,dic)
#      25     else:
# ---> 26         dic, poblacion = nueva_generacion(poblacion,n_padres,n_directos,dic)
#      27         print('.',end='')
#      28 return mejores
#
# Cell In[122], line 4, in nueva_generacion(poblacion, n_padres, n_directos, dic)
#       3 def nueva_generacion(poblacion, n_padres, n_directos, dic):
# ----> 4     padres, pad_dic = seleccion_por_torneo(poblacion, n_padres, dic)
#       6     directos, dir_dic = seleccion_por_torneo(poblacion, n_directos, dic)
#       8     nuevo_dic = dic.copy()
#
# Cell In[22], line 8, in seleccion_por_torneo(poblacion, num_seleccionados, dic)
#       5 seleccion = []
#       7 for _ in range(num_seleccionados):
# ----> 8     sel_torneo = selecciona_uno_por_torneo(poblacion, nuevo_dic)
#      10     nuevo_dic = sel_torneo[1]
#      12     seleccion.append(sel_torneo[0])
#
# Cell In[20], line 12, in selecciona_uno_por_torneo(poblacion, dic)
#      10 for ind in participantes:
#      11     if not ind in nuevo_dic:
# ---> 12         nuevo_dic[ind] = fitness_1(ind)
#      13     if nuevo_dic[ind] > nuevo_dic[max_cand]:
#      14         max_cand = ind
#
# Cell In[18], line 2, in fitness_1(ind)
#       1 def fitness_1(ind):
# ----> 2     return np.sum(np.absolute(decodifica(ind) - IM2ARRAY))
#
# Cell In[13], line 5, in decodifica(ind)
#       3 array_sal = np.zeros(im2array_shape,dtype='uint32')
#       4 array_255 = np.full(im2array_shape,255,dtype='uint32')
# ----> 5 for (x,y,dx,dy,c) in ind:
#       6     array_sal[x:x+dx,y:y+dy]+= 255 - c
#       7 mini = np.minimum(array_sal,array_255)
#
# TypeError: cannot unpack non-iterable int object

# %%
plt.plot(sal_ag_2[1:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 plt.plot(sal_ag_2[1:])
#       2 plt.show()
#
# NameError: name 'sal_ag_2' is not defined
